# %% [markdown]
# <a href="https://colab.research.google.com/github/denisgoritko/ecommerce-sales-analysis-project/blob/main/Portfolio_Project_Sales_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Посилання на дашборд

# %% [markdown]
# [Sales Analysis](https://public.tableau.com/app/profile/alex.kybuk/viz/Portfolio1_17552495375370/Portfolio1Dashboard?publish=yes)

# %% [markdown]
# # Висновки аналізу датасету

# %% [markdown]
# ### Короткий опис датасету

# %% [markdown]
# **Згідно з інформацією про наш датасет, маємо наступні дані:**
#
# *   *Загальна кількість колонок:* **16**
#
# *   *Кількість колонок числового типу:* **4** (`session_id`, `account_verified`, `account_unsubscribed`, `price`)
# *   *Кількість колонок категоріального типу:* **11** (`continent`, `country`, `device`, `browser`, `device_model_name`, `operating_system`, `browser_language`, `traffic_source_information`, `product_category`, `product_name`, `short_product_description`)
# *   *Кількість колонок типу datetime:* **1** (`date`)
# *   *Кількість унікальних сесій:* **349 545**
# *   *Кількість унікальних аккаунтів:* **27 946**
# *   *Кількість верифікованих аккаунтів:* **20 036**
# *   *Кількість неверифікованих аккаунтів:* **7 910**
# *   *Кількість аккаунтів, підписаних на розсилку:* **23 211**
# *   *Кількість аккаунтів, відписаних від розсилки:* **4 735**
# *   *Кількість продажів (транзакцій):* **33 538**
# *   *Загальний дохід від продажів:* **31 971 731 $**
# *   *Кількість унікальних проданих категорій:* **14**
# *   *Рассматриваемый період:* **з 1 листопада 2020 по 31 січня 2021**
# *   *Наявність пропущених значень:* **Так**
# *   *Колонки з найбільшим
# кількість пропусків:* `product_category`, `product_name`, `price`, `short_product_description`, `browser_language`.
# *    *Причина пропусків в колонках, пов'язаних з товарами (`product_category`, `product_name`, `price`...):* наш набір даних включає *всі* сесії, а не тільки сесії з покупками. Ці поля залишаються пустыми, якщо в ході сесії замовлення не було оформлено.

# %% [markdown]
# ## Аналіз продажів

# %% [markdown]
# ### Топ - 3 континенти за найбільшими продажами

# %% [markdown]
# На основі розрахунків, ми можемо зробити наступні висновки:
#
# * **Явне домінування:** Континент **Americas**  є абсолютним лідером як за **загальною сумою продажів** (понад 17,6 млн), так і за **кількістю замовлень** (понад 18,5 тис.).
#
# * **Масштаб ринку:** Ринок Америки настільки великий, що генерує більше доходу та замовлень, ніж Азія та Європа **разом узяті**.
#
# * **Послідовний рейтинг:** Порядок континентів у топ-3 є **однаковим** для обох показників:
#     1.  **Americas**
#     2.  **Asia**
#     3.  **Europe**

# %% [markdown]
# ### Топ - 5 країн за найбільшими продажами

# %% [markdown]
# Аналіз топ-5 країн показує чітку картину:
#
# * **Домінування США 🇺🇸:** **United States** є беззаперечним лідером, значно випереджаючи всі інші країни як за **сумою продажів** (майже 14 млн), так і за **кількістю замовлень** (понад 14,6 тис.).
#
# * **Ідентичний рейтинг:** Важливо відзначити, що топ-5 країн є **однаковим** для обох показників (суми та кількості). Це свідчить про те, що вища кількість замовлень прямо призводить до вищої загальної суми продажів у цих регіонах.
#
# * **Порядок ринків:** Рейтинг ринків виглядає так:
#     1.  **United States**
#     2.  **India**
#     3.  **Canada**
#     4.  **United Kingdom**
#     5.  **France**

# %% [markdown]
# ### Топ-10 категорій товарів за загальною сумою продажів

# %% [markdown]
# Аналіз продажів за категоріями товарів показує, де зосереджений основний дохід:
#
# * **Лідерство "М'яких меблів":** Категорія **"Sofas & armchairs"** (Дивани та крісла)  є абсолютним лідером, згенерувавши понад 8,3 млн доходу.
# * **Велика трійка:** Перші три категорії (**"Sofas & armchairs"**, **"Chairs"** та **"Beds"**) разом приносять понад 19,4 млн, що складає абсолютну більшість доходу від топ-10.
# * **Чітке падіння:** Існує значний розрив у доходах між першими 7 категоріями (які приносять мільйони) та останніми трьома ("Chests of drawers", "Bar furniture", "Children's furniture"), які генерують менше 1 мільйона кожна.

# %% [markdown]
# ### Топ-10 категорій товарів у країні з найбільшими продажами

# %% [markdown]
# Цей аналіз дає нам один з найважливіших інсайтів усього проекту:
#
# * **Повна ідентичність:** Список **Топ-10 категорій**  у **США** є **абсолютно ідентичним** за складом та порядком до **загального (глобального) Топ-10**.
#
# * **Підтвердження домінування:** Це прямо підтверджує наш попередній висновок. Ринок **США** 🇺🇸 настільки домінує (генеруючи майже 14 млн доходу), що купівельні переваги американських клієнтів фактично **диктують** загальні світові тренди продажів для компанії.
#
# * **Фокус:** Будь-яка маркетингова стратегія, орієнтована на просування цих топ-10 категорій, матиме найбільший вплив саме на ринку США.

# %% [markdown]
# ### Продажі у розрізі типів та моделей девайсів (у % від загальних продажів)

# %% [markdown]
# Аналіз показує чітку ієрархію пристроїв, які генерують дохід.
#
# ### 1. Загальний розподіл за Типом Девайсу
#
# Розрахунок відсотків продажів показує чіткий розподіл за платформами:
#
# * **Desktop (59.00%):** Настільні комп'ютери є основним джерелом доходу, генеруючи майже 60% всіх продажів.
# * **Mobile (38.73%):** Мобільні пристрої — це другий за важливістю сегмент.
# * **Tablet (2.26%):** Планшети наразі генерують дуже незначну частку продажів.
#
# ### 2. Глибший аналіз Моделей (відфільтровані дані)
#
# Коли ми відфільтрували дані, щоб подивитися лише на продажі з конкретних моделей (виключивши загальні категорії, як 'desktop' та браузери), ми бачимо таку картину:
#
# * **iPhone (71.92%):** **iPhone** є абсолютно домінуючою *моделлю* пристрою серед відфільтрованих даних, приносячи майже 72% доходу в цьому сегменті.
# * **ChromeBook (20.50%):** ChromeBook  посідає друге місце.
# * **Інші пристрої:** iPad, Pixel 4 XL та Pixel 3 складають значно меншу частку.
#
# **Загальний підсумок:** Хоча **desktop** приносить найбільше грошей загалом, серед мобільних пристроїв та ноутбуків домінує **iPhone**.

# %% [markdown]
# ### Продажі за джерелами трафіку (у % від загальних продажів)

# %% [markdown]
# Розподіл доходу за каналами трафіку показує чітку залежність від пошукових систем:
#
# * **Домінування пошуку:** **"Organic Search"** (Органічний пошук) є найціннішим каналом, генеруючи **35.76%** усього доходу.
# * **Пошук = 62%:** Якщо додати **"Paid Search"** (Платний пошук) (26.62%), то стає очевидно, що пошукові системи (платні та безкоштовні) разом приносять понад **62%** усього доходу компанії.
# * **Інші канали:** **"Direct"** (Прямий трафік) є третім за важливістю (23.44%), тоді як **"Social Search"** (Соціальні мережі) та **"Undefined"** (Невизначений трафік) приносять значно менше 10% кожен.

# %% [markdown]
# ### Відсоток зареєстрованих користувачів який підтвердив свою електронну адресу

# %% [markdown]
# Аналіз зареєстрованих користувачів показує, що:
#
# * **Більшість верифіковані:** **71.7%** зареєстрованих користувачів **підтвердили** свою електронну адресу.
# * **Сегмент для активації:** Відповідно, **28.3%** користувачів, які пройшли реєстрацію, **не завершили** цей крок. Це може бути сегментом для запуску кампаній з реактивації або пропозиції бонусу за верифікацію.

# %% [markdown]
# ### Відсоток зареєстрованих користувачів які відписався від розсилки

# %% [markdown]
# Аналіз поведінки зареєстрованих користувачів щодо розсилок показує:
#
# * **Рівень відписок:** **16.9%** (або приблизно кожен шостий зареєстрований користувач) прийняв рішення **відписатися** від маркетингової розсилки.
# * **Утримання:** Це означає, що **83.1%** зареєстрованих користувачів залишаються активними підписниками.

# %% [markdown]
# ### Чи відрізняється поведінка (у плані продажів) тих, хто відписався від розсилки та тих, хто досі підписаний?

# %% [markdown]
# Поведінка підписаних vs. відписаних
#
# * Кількість покупок (count): Користувачі, які залишилися підписаними, зробили набагато більше покупок (2334), ніж ті, хто відписався (447).
#
# * Середній чек (mean): Користувачі, які відписалися, витрачають в середньому трохи більше грошей за одну покупку (965.82), ніж підписані (921.50). Медіана (50%) також вища (450.00 проти 395.00).
#
# Підсумок: Хоча підписані користувачі купують набагато частіше, ті, хто відписався, демонструють трохи вищий середній чек за покупку.

# %% [markdown]
# ### В яких країнах найбільше зареєстрованих користувачів?

# %% [markdown]
# Аналіз топ-10 країн за кількістю **зареєстрованих користувачів** показує схожу картину, яку ми бачили у продажах:
#
# * **Домінування США 🇺🇸:** **United States** є абсолютним лідером, маючи **12 384** зареєстрованих користувачів.
# * **Значний розрив:** Кількість зареєстрованих користувачів у США в **4.6 рази** більша, ніж у країни на другому місці (Індія  з 2 687), і більша, ніж у всіх інших 9 країнах списку *разом узятих*.
# * **Топ-3:** Як і в аналізі продажів, топ-3 країни складають **United States**, **India** та **Canada** .

# %% [markdown]
# ### Чи збігається популярність браузера з обсягом продажів?

# %% [markdown]
# Аналіз чітко показує, що **популярність браузера прямо відповідає його прибутковості**.
#
# Ось що ми бачимо:
# * **Домінування Chrome :** Браузер **Chrome** є абсолютним лідером з величезним відривом як за **сумою продажів** (понад 20 мільйонів), так і за **кількістю сесій** (понад 200 тисяч).
# * **Чітке друге місце:** **Safari** посідає впевнене друге місце в *обох* категоріях, але значно відстає від Chrome.
# * **Ідентичні списки:** Порядок браузерів у списку за грошима практично повністю збігається з порядком у списку за кількістю.
#
# **Загальний підсумок:** Немає жодних сюрпризів. Браузери, якими користується найбільше людей, приносять найбільше грошей.

# %% [markdown]
# ### Чи витрачають користувачі Apple (iOS/Mac) в середньому більше, ніж користувачі Android/Windows?

# %% [markdown]
# Ми перевірили гіпотезу про те, чи витрачають користувачі Apple (Macintosh/iOS)  в середньому більше, ніж користувачі Android/Windows .
#
# * **Гіпотеза НЕ підтвердилася:** Наші дані показують, що **Android** (978.25) та **Windows** (976.63) насправді мають *трохи вищий* середній чек, ніж **Macintosh** (973.55) та **iOS** (948.74).
#
# * **Головний інсайт:** Однак, найважливіший висновок полягає в тому, що всі середні значення знаходяться в дуже вузькому діапазоні (930-980).
#
# **Загальний підсумок:** **Операційна система не має суттєвого впливу** на середню суму покупки.

# %% [markdown]
# ## Аналіз динаміки продажів

# %% [markdown]
# ### Загальні продажі за кожну дату, чи спостерігається сезонність продажів?

# %% [markdown]
# Лінійний графік загальної динаміки продажів дозволяє зробити чіткий висновок про сезонність.
#
# Ось що ми бачимо:
#
# * **Чіткі святкові піки:** На графіку є два величезних піки продажів.
#     * Перший, найбільший, припадає на **кінець листопада** (приблизно 24-27 листопада). Це майже напевно **"Чорна п'ятниця" / "Кіберпонеділок"**.
#     * Другий великий пік — на **кінець грудня** (приблизно 21-25 грудня), що чітко відповідає фінальному ажіотажу перед **Різдвом**.
#
# * **Спади після свят:** Одразу після цих піків (особливо після різдвяного) видно різкі падіння продажів, що є типовою поведінкою споживачів.
#
# * **"Затишшя" у січні:** Продажі в січні виглядають загалом значно нижчими та стабільнішими, ніж у пікові місяці листопад і грудень.
#
# **Загальний підсумок:** Так, ми спостерігаємо дуже **сильну сезонність**, яка повністю прив'язана до головних зимових свят і розпродажів.

# %% [markdown]
# ### Динаміка продажів

# %% [markdown]
# Загальний висновок по Динаміці продажів
#
# Аналіз усіх лінійних графіків  (загального, за континентами, трафіком і девайсами) виявив два ключові патерни:
#
# * **1. Спільний патерн (Сезонність):** Усі графіки показують **однаковий загальний тренд**. Динаміка продажів повністю визначається **сезонністю**, з чіткими піками  наприкінці листопада (**Чорна п'ятниця**) та наприкінці грудня (**Різдво**). Це свідчить про те, що глобальні святкові події є головним драйвером продажів у всіх сегментах.
#
# * **2. Ключові сегменти (Девайси):** Графік динаміки продажів у розрізі типів девайсів чітко показує, що хоча загальний *патерн* однаковий, основний обсяг доходу генерують два сегменти: **desktop**  та **mobile** . Лінія 'tablet' лежить майже на нулі.

# %% [markdown]
# ## Зведені таблиці

# %% [markdown]
# ### Кількість сесій у розрізі каналів трафіку та типів девайсів

# %% [markdown]
# * **Домінування Desktop :** **'desktop'** є основним пристроєм для залучення сесій *у кожному окремому каналі трафіку*. У всіх каналах сесій з 'desktop' більше, ніж з 'mobile'.
#
# * **Головний канал:** **'Organic Search'** (Органічний пошук) є найбільшим джерелом сесій загалом (понад 124 тис. сесій, якщо скласти desktop, mobile та tablet).
#
# * **Найбільший сегмент:** Найбільша окрема комбінація — це **'Organic Search'** на **'desktop'** (72 622 сесії).
#
# * **Ніша планшетів :** **'tablet'** становить дуже малу частку сесій у всіх каналах.

# %% [markdown]
# ### Загальні продажі за категоріями товарів (топ-10 категорій) у різних країнах (топ-5 країн)

# %% [markdown]
# Ця зведена таблиця  дає нам глибоке розуміння того, *де* продаються *які* товари, і підтверджує кілька наших попередніх висновків:
#
# * **Абсолютне домінування США 🇺🇸:** У **кожній** з топ-10 категорій товарів, **United States** генерує значно більше доходу, ніж будь-яка інша країна. Часто продажі в США перевищують сумарні продажі в інших чотирьох країнах.
#
# * **Подібність ринків:** **India** 🇮🇳 та **Canada** 🇨🇦 демонструють дуже схожу купівельну поведінку. Їхні обсяги продажів у багатьох категоріях (наприклад, "Beds", "Chairs", "Sofas & armchairs") є досить близькими.
#
# * **Послідовність категорій:** Топ-3 категорії (Sofas & armchairs, Chairs, Beds) є лідерами продажів не лише в загальному заліку, але й *усередині* кожної з топ-5 країн. Це свідчить про універсальний попит на ці товари.

# %% [markdown]
# ### Середній чек у розрізі континентів та типів девайсів

# %% [markdown]
# Ця зведена таблиця показує **середню суму покупки** (`mean price`) , сегментовану за моделлю пристрою та континентом.
#
# * **Відсутність чіткого лідера:** На відміну від *загальних продажів* (де домінує Америка), у *середньому чеку* немає єдиного континенту-лідера. Показники сильно коливаються.
#
# * **Висока волатильність:** Середній чек є дуже нестабільним. Наприклад:
#     * **Pixel 3**  має надзвичайно високий середній чек в Океанії (2196) та Азії (1421), але значно нижчий в Європі (741).
#     * **iPhone**  показує відносно стабільний середній чек у основних регіонах (914 в Америці, 979 в Азії, 989 в Європі).
#
# * **Пропуски даних (NaN):** Велика кількість `NaN` (Not a Number) свідчить про те, що для багатьох специфічних комбінацій (наприклад, `Pixel 4 XL` в Океанії) не було **жодного** продажу.
#
# * **Схожість основних ринків:** На трьох основних ринках (Americas, Asia, Europe) середній чек для більшості поширених моделей (`iPhone`, `ChromeBook`) переважно коливається в діапазоні 900-1000. Це підтверджує наш попередній висновок, що тип пристрою не має вирішального впливу на *середню* суму покупки.

# %% [markdown]
# ### Загальна сума продажів для кожної комбінації Каналу Трафіку та Типу Девайсу

# %% [markdown]
# Ця зведена таблиця показує **загальну суму продажів**, згруповану за типом девайсу та каналом трафіку.
#
# * **Домінування Mobile:** На відміну від *кількості сесій* (де лідирував desktop), у *продажах* **'mobile'** є абсолютним лідером. Мобільні пристрої генерують **найбільше доходу в кожному окремому каналі трафіку**.
#
# * **Найприбутковіший канал:** **'Organic Search'** (Органічний пошук) є найприбутковішим каналом загалом, і це здебільшого завдяки мобільним продажам.
#
# * **Найбільший сегмент:** Найбільша і найважливіша комбінація для бізнесу — це **'Organic Search'** на **'mobile'**, яка згенерувала понад 4,4 млн доходу.

# %% [markdown]
# ## Статистичний аналіз взаємозв’язків

# %% [markdown]
# ### Кількість сесій та загальні продажі за кожну дату. Чи корелюють ці показники?

# %% [markdown]
#   Висновок: Кореляція між Сесіями та Продажами
#
# Ми проаналізували взаємозв'язок між **кількістю сесій** 🖱️ та **загальними продажами**  за кожну дату, щоб з'ясувати, чи корелюють ці показники.
#
#  1. Візуальний аналіз (Діаграма розсіювання )
#
# Діаграма розсіювання чітко показала, що показники корелюють: від кількості сесій залежить сума продажів.
#
# * **Сильна позитивна кореляція:** Точки чітко шикуються в лінію, що йде з лівого нижнього кута в правий верхній.
# * **Позитивна:** Коли один показник (кількість сесій) зростає, інший (сума продажів) теж зростає.
# * **Сильна:** Точки лежать дуже щільно навколо уявної прямої лінії.
#
#  2. Статистичний аналіз (Коефіцієнт Пірсона)
#
# Розрахунок коефіцієнта кореляції Пірсона підтвердив візуальні спостереження:
#
# * **Коефіцієнт кореляції (r): 0.791**
# * **P-value: 6.4835...e-21**
#
# **Загальний підсумок:**
# 1.  Значення **r = +0.791** вказує на **сильну позитивну кореляцію**.
# 2.  **P-value** (яке практично дорівнює нулю) набагато **менше** за стандартний поріг 0.05. Це означає, що результат є **статистично значущим** і не є випадковістю.

# %% [markdown]
# ### Чи корелюють між собою продажі на різних континентах? Візьми топ-3 континенти. Проаналізуй статистичну значущість взаємозв’язків.

# %% [markdown]
#   Висновок: Кореляція продажів між Топ-3 Континентами
#
# Ми попарно проаналізували, чи корелюють (рухаються разом) щоденні продажі на трьох наших найбільших ринках: **'Americas'**, **'Asia'** та **'Europe'**.
#
#  Статистичний аналіз (Коефіцієнт Пірсона)
#
# * **--- Кореляція: Americas vs. Asia ---**
#     * **Коефіцієнт (r): 0.7920**
#     * **P-value: 5.409e-21** (Статистично значуще)
#
# * **--- Кореляція: Americas vs. Europe ---**
#     * **Коефіцієнт (r): 0.7706**
#     * **P-value: 2.671e-19** (Статистично значуще)
#
# * **--- Кореляція: Asia vs. Europe ---**
#     * **Коефіцієнт (r): 0.7684**
#     * **P-value: 3.864e-19** (Статистично значуще)
#
# **Загальний підсумок:**
# Динаміка продажів на топ-3 континентах **сильно та позитивно корелює** . Усі коефіцієнти (r > 0.76) є високими, і всі результати є **статистично значущими** (p-value < 0.05).
#
# Це підтверджує наш попередній висновок про те, що продажі зумовлені **глобальними подіями** (як Чорна п'ятниця та Різдво), які впливають на всі ринки **одночасно**.

# %% [markdown]
# ### Чи корелюють між собою продажі за різними каналами трафіку? Проаналізуй статистичну значущість взаємозв’язків.

# %% [markdown]
#   Висновок: Кореляція продажів між Каналами трафіку
#
# Ми провели попарний кореляційний аналіз, щоб з'ясувати, чи пов'язана динаміка щоденних продажів  між різними каналами трафіку .
#
#  Статистичний аналіз (Коефіцієнт Пірсона)
#
# Усі пари каналів показали **статистично значущу** (p < 0.05) **позитивну кореляцію**. Однак сила цього зв'язку різна:
#
# * **Дуже сильна кореляція (r > 0.8):**
#     * `Organic Search vs. Paid Search`: **(r): 0.8701**
#     * `Direct vs. Organic Search`: **(r): 0.8378**
#     * `Direct vs. Paid Search`: **(r): 0.8141**
#     * *Висновок:* Динаміка продажів з "великої трійки" каналів (Direct, Organic, Paid) рухається майже синхронно. Це логічно, оскільки всі вони сильно залежать від загальних святкових піків .
#
# * **Помірна кореляція (r ≈ 0.5 - 0.6):**
#     * `Direct vs. Social Search`: **(r): 0.6041**
#     * `Paid Search vs. Social Search`: **(r): 0.5964**
#     * `Organic Search vs. Social Search`: **(r): 0.5831**
#     * `Organic Search vs. Undefined`: **(r): 0.5261**
#     * `Paid Search vs. Undefined`: **(r): 0.5220**
#     * `Direct vs. Undefined`: **(r): 0.5175**
#     * *Висновок:* 'Social Search' та 'Undefined' також корелюють з основними каналами, але зв'язок слабший.
#
# * **Слабша кореляція (r < 0.5):**
#     * `Social Search vs. Undefined`: **(r): 0.4551**
#     * *Висновок:* Найслабший зв'язок спостерігається між двома найменшими каналами.
#
# **Загальний підсумок:** Усі канали трафіку рухаються в одному напрямку (позитивна кореляція), що, ймовірно, зумовлено глобальною сезонністю. Однак найсильніший зв'язок існує між основними каналами (Organic, Paid, Direct).

# %% [markdown]
# ### Чи корелюють між собою продажі за топ-5 категоріями товарів? Проаналізуй статистичну значущість взаємозв’язків.

# %% [markdown]
#   Висновок: Кореляція продажів між Топ-5 Категоріями
#
# Ми провели попарний кореляційний аналіз, щоб з'ясувати, чи пов'язана динаміка щоденних продажів  між **топ-5 найприбутковішими категоріями товарів** 🛍️.
#
#  Статистичний аналіз (Коефіцієнт Пірсона)
#
# Усі 10 пар показали **статистично значущу** (p < 0.05) **позитивну кореляцію**. Сила зв'язку, здебільшого, є **помірною**.
#
# * --- **Beds vs. Bookcases & shelving units** ---
#     * **Коефіцієнт (r): 0.5929**
#     * **P-value: 1.154e-09** (Статистично значуще)
#
# * --- **Beds vs. Cabinets & cupboards** ---
#     * **Коефіцієнт (r): 0.5146**
#     * **P-value: 2.910e-07** (Статистично значуще)
#
# * --- **Beds vs. Chairs** ---
#     * **Коефіцієнт (r): 0.5545**
#     * **P-value: 2.079e-08** (Статистично значуще)
#
# * --- **Beds vs. Sofas & armchairs** ---
#     * **Коефіцієнт (r): 0.5354**
#     * **P-value: 7.687e-08** (Статистично значуще)
#
# * --- **Bookcases & shelving units vs. Cabinets & cupboards** ---
#     * **Коефіцієнт (r): 0.5394**
#     * **P-value: 5.867e-08** (Статистично значуще)
#
# * --- **Bookcases & shelving units vs. Chairs** ---
#     * **Коефіцієнт (r): 0.6371**
#     * **P-value: 2.504e-11** (Статистично значуще)
#
# * --- **Bookcases & shelving units vs. Sofas & armchairs** ---
#     * **Коефіцієнт (r): 0.6662** (Найсильніший зв'язок)
#     * **P-value: 1.406e-12** (Статистично значуще)
#
# * --- **Cabinets & cupboards vs. Chairs** ---
#     * **Коефіцієнт (r): 0.5729**
#     * **P-value: 5.465e-09** (Статистично значуще)
#
# * --- **Cabinets & cupboards vs. Sofas & armchairs** ---
#     * **Коефіцієнт (r): 0.6576**
#     * **P-value: 3.415e-12** (Статистично значуще)
#
# * --- **Chairs vs. Sofas & armchairs** ---
#     * **Коефіцієнт (r): 0.5782**
#     * **P-value: 3.638e-09** (Статистично значуще)
#
# **Загальний підсумок:**
# Як і очікувалося, продажі всіх топ-категорій рухаються в одному напрямку, що зумовлено глобальною сезонністю (святами). Однак, на відміну від каналів трафіку, сила кореляції тут лише **помірна** (в основному $r \approx 0.5 - 0.67$). Це свідчить про те, що хоча люди купують більше в святкові дні, вони **не обов'язково** купують "Sofas" *разом* з "Beds" в той самий день. Покупницька поведінка є більш різноманітною.

# %% [markdown]
# ### Чи корелюють між собою продажі на різних типах девайсів?

# %% [markdown]
#  Висновок: Кореляція продажів між Типами Девайсів
#
# Ми провели попарний кореляційний аналіз, щоб з'ясувати, чи пов'язана динаміка щоденних продажів  між різними типами девайсів .
#
#  Статистичний аналіз (Коефіці B-T)
#
# * **--- desktop vs. mobile ---**
#     * **Коефіцієнт (r): 0.8732** (Дуже сильна кореляція)
#     * **P-value: 7.719e-30** (Статистично значуще)
#
# * **--- desktop vs. tablet ---**
#     * **Коефіцієнт (r): 0.6014** (Помірна кореляція)
#     * **P-value: 2.316e-10** (Статистично значуще)
#
# * **--- mobile vs. tablet ---**
#     * **Коефіцієнт (r): 0.5674** (Помірна кореляція)
#     * **P-value: 3.693e-09** (Статистично значуще)
#
# **Загальний підсумок:**
# 1.  **Сильний зв'язок Desktop-Mobile:** Існує **дуже сильний** позитивний зв'язок ($r \approx 0.87$) між продажами на 'desktop' та 'mobile'. Їхня динаміка продажів рухається майже синхронно.
# 2.  **Помірний зв'язок з Tablet:** Продажі на 'tablet' також корелюють з 'desktop' та 'mobile' ($r \approx 0.56 - 0.60$), але цей зв'язок помітно слабший.
# 3.  **Глобальний тренд:** Усі три типи девайсів рухаються в одному напрямку (всі $r$ позитивні та статистично значущі), що знову ж таки підтверджує, що **глобальна сезонність**  (свята, розпродажі) є головним фактором, який впливає на продажі на всіх платформах одночасно.

# %% [markdown]
# ### Який канал трафіку є "найефективнішим"?

# %% [markdown]
#  Висновок: Аналіз Коефіцієнта Конверсії (CR) за Каналами Трафіку
#
# Ми розрахували Коефіцієнт Конверсії (CR) , щоб визначити, який канал трафіку є **"найефективнішим"** у перетворенні сесій на покупки.
#
# `CR = (Кількість Покупок / Загальна Кількість Сесій) * 100%`
#
#  Результати розрахунку (Оновлені):
#
# | traffic_source_information | Total_Sessions | Total_Purchases | Conversion_Rate_Percent |
# | :--- | :---: | :---: | :---: |
# | **Social Search** | 27,914 | 2,716 | **9.73%** |
# | **Direct** | 81,382 | 7,800 | **9.58%** |
# | **Paid Search** | 94,341 | 9,042 | **9.58%** |
# | **Undefined** | 21,483 | 2,059 | **9.58%** |
# | **Organic Search** | 124,425 | 11,921 | **9.58%** |
#
# ### Висновки (Оновлені):
#
# 1.  **Найефективніший канал:** **'Social Search'** (Соціальні мережі)  несподівано виявився **найефективнішим** каналом з **CR = 9.73%**.
#
# 2.  **Поразительна однаковість:** Всі інші чотири канали (включно з нашими найбільшими джерелами доходу, як-от 'Organic Search' та 'Paid Search') демонструють **абсолютно однаковий** коефіцієнт конверсії **9.58%**.
#
# 3.  **Ефективність vs. Обсяг:** Це ключовий інсайт. Хоча 'Organic Search' приносить *найбільший загальний дохід* (завдяки величезній кількості сесій), він **не** є найефективнішим. 'Social Search', хоч і має менше сесій, краще перетворює їх на покупців.

# %% [markdown]
# ## Статистичний аналіз відмінностей між групами.

# %% [markdown]
# ### Проаналізуй продажі за кожну дату зареєстрованих та незареєстрованих користувачів. Створи відповідні вибірки, проаналізуй розподіли даних в обох вибірках. Підбери відповідний статистичний тест для порівняння вибірок. Зроби висновок щодо статистичної значущості отриманих результатів.

# %% [markdown]
#  Висновок: Аналіз Зареєстрованих vs. Незареєстрованих користувачів
#
# Ми провели статистичний аналіз, щоб з'ясувати, чи існує значуща різниця в *сумах покупок* (чеках)  між зареєстрованими та незареєстрованими користувачами.
#
#  1. Візуальний аналіз (Box Plot)
# * **Результат:** Графік показав, що "коробки" (медіани та 50% даних) для груп **0 (Незареєстровані)** та **1 (Зареєстровані)** виглядають дуже схоже.
# * **Спостереження:** Обидві групи мають багато "викидів" (outliers) — покупок на аномально великі суми, що вказує на не-нормальний розподіл.
#
#  2. Тест на нормальність (Шапіро-Вілк)
# * **Результат:** Обидва p-value (`e-52` та `e-37`) є практично нульовими (набагато менше 0.05).
# * **Висновок:** Дані **НЕ розподілені нормально**. Це означає, що ми не можемо використовувати T-тест і повинні обрати непараметричний аналог.
#
#  3. Фінальний тест (Манна-Вітні U-тест)
# * **Результат:** **P-value = 0.2704**
# * **Висновок:** Оскільки P-value (0.27) > 0.05, ми **не можемо відхилити нульову гіпотезу**.
#
# ---
#
#  Загальний висновок
#
# Незважаючи на те, що **зареєстровані користувачі роблять значно більше покупок** (1,989 проти 792), **статистично значущої різниці в сумі їхнього індивідуального "чека"** не виявлено.

# %% [markdown]
# ### Проаналізуй кількість сесій за різними каналами трафіку. Підбери відповідний тест. Чи є статистично значущі відмінності між групами?

# %% [markdown]
#  Висновок: Кореляція сесій між Каналами Трафіку
#
# Ми провели попарний кореляційний аналіз, щоб з'ясувати, чи пов'язана динаміка щоденних сесій  між різними каналами трафіку .
#
#  Статистичний аналіз (Коефіцієнт Пірсона)
#
# Усі пари каналів показали **статистично значущу** (p < 0.05) **позитивну кореляцію**. Сила цього зв'язку надзвичайно висока:
#
# * **Майже ідеальний зв'язок (r > 0.98):**
#     * `Organic Search vs. Paid Search`: **(r): 0.9860**
#     * `Direct vs. Organic Search`: **(r): 0.9840**
#     * `Direct vs. Paid Search`: **(r): 0.9823**
#     * *Висновок:* Динаміка "великої трійки" (Organic, Paid, Direct) є практично синхронною.
#
# * **Дуже сильний зв'язок (r > 0.9):**
#     * `Social Search vs. Undefined`: **(r): 0.9335**
#     * `Direct vs. Social Search`: **(r): 0.9269**
#     * `Organic Search vs. Social Search`: **(r): 0.9076**
#     * `Paid Search vs. Social Search`: **(r): 0.9044**
#     * *Висновок:* 'Social' та 'Undefined' також дуже сильно пов'язані як між собою, так і з "великою трійкою".
#
# * **Сильний зв'язок (r ≈ 0.8):**
#     * `Direct vs. Undefined`: **(r): 0.8258**
#     * `Organic Search vs. Undefined`: **(r): 0.7978**
#     * `Paid Search vs. Undefined`: **(r): 0.7893**
#
# **Загальний підсумок:**
# Усі канали трафіку демонструють **дуже сильну позитивну кореляцію**  (всі $r$ > 0.78). Це переконливо свідчить про те, що головним драйвером трафіку є **глобальна сезонність** (свята, розпродажі), яка впливає на всі канали **одночасно**.

# %% [markdown]
# ### Чи відрізняється статистично доля сесій з органічним трафіком у Європі та Америці? Підбери відповідний тест. Проведи потрібні обчислення для створення вхідних даних до тесту.

# %% [markdown]
# Висновок: Порівняння долі органічного трафіку (Europe vs. Americas)
#
# Ми провели аналіз, щоб з'ясувати, чи **відрізняється статистично *щоденна доля* (daily proportion)  сесій з органічним трафіком** у Європі  та Америці .
#
#  1. Підбір тесту
#
# Оскільки ми порівнюємо дві **незалежні** групи (Europe та Americas) і ми не можемо припустити, що дані розподілені "нормально", ми обрали **Тест Манна-Вітні (Mann-Whitney U test)**.
#
#  2. Статистичний аналіз (Тест Манна-Вітні)
#
# * **--- Тест Манна-Вітні (Доля органічного трафіку) ---**
# * **Статистика U-тесту:** 4288.0
# * **P-value:** 0.8779
#
# **Загальний підсумок:**
# Результат **НЕ є статистично значущим**.
#
# Оскільки **P-value (0.8779)** набагато **більше** за наш поріг 0.05, ми не можемо відхилити нульову гіпотезу. Це означає, що **немає суттєвої різниці** в *щоденній долі* органічного трафіку між Європою та Америкою.

# %% [markdown]
# ### Порівнюємо середні продажі між усіма 5 каналами трафіку одночасно

# %% [markdown]
#  Висновок: Аналіз відмінностей між 5 Каналами Трафіку (ANOVA)
#
# Ми провели тест **ANOVA (F-тест)**, щоб з'ясувати, чи існує статистично значуща **різниця**  в *середній*  кількості щоденних сесій між *усіма 5 каналами трафіку* одночасно.
#
#  Статистичний аналіз (ANOVA)
#
# * **--- Тест ANOVA (F-тест) для 5 каналів трафіку ---**
# * **F-статистика:** 439.76
# * **P-value:** 8.433e-155 (це число надзвичайно близьке до нуля)
#
# **Загальний підсумок:**
# Результат є **статистично значущим**.
#
# Оскільки **P-value** (яке практично дорівнює нулю) набагато **менше** за наш поріг 0.05, ми відхиляємо нульову гіпотезу. Це означає, що **існує значуща різниця** в *середній* кількості щоденних сесій принаймні між двома каналами.

# %% [markdown]
# ##  Загальний висновок по проекту
#
# На основі комплексного аналізу даних (SQL, Python) та статистичних тестів (Pearson, Mann-Whitney, ANOVA) ми можемо скласти чіткий портрет бізнесу та виявити ключові інсайти.
#
# ---
#
# ### 1. Продажі повністю залежать від Сезонності
#
# Це **найголовніший висновок** усього аналізу. Динаміка продажів не є стабільною, а повністю визначається двома подіями:
#
# * **Пік 1:** **Чорна п'ятниця / Кіберпонеділок** (кінець листопада).
# * **Пік 2:** **Різдвяний розпродаж** (кінець грудня).
#
# Наш кореляційний аналіз підтвердив це: продажі на **всіх** континентах, **всіх** типах девайсів та через **всі** канали трафіку мають **дуже сильну позитивну кореляцію** (більшість $r > 0.75 - 0.98$). Це означає, що вони не рухаються незалежно; вони всі рухаються **синхронно**, реагуючи на ті самі глобальні святкові події.
#
# ---
#
# ### 2. Існує чіткий "Золотий сегмент"
#
# Ми можемо точно описати найціннішого клієнта:
#
# * **Де? (Географія):** **США** . Цей ринок домінує настільки, що генерує більше доходу, ніж Індія та Канада разом узяті. Купівельні переваги в США (Топ-10 категорій) **диктують** загальносвітові тренди.
# * **Звідки? (Канал):** **Пошукові системи** 🖱️. **'Organic Search'** (35.76%) та **'Paid Search'** (26.62%) разом приносять понад **62%** усього доходу.
# * **Як? (Платформа):** **Desktop** . На нього припадає **59%** усього доходу, що робить його найважливішою платформою.
#
# ---
#
# ### 3. Що купують? (Продукти)
#
# * **"Велика трійка"**: Більшість доходу приносять три категорії: **"Sofas & armchairs"**  (8.3 млн), **"Chairs"** (6.1 млн) та **"Beds"** (4.9 млн).
#
# ---
#
# ### 4. Ключові статистичні інсайти
#
# 1.  **"Найефективніший" канал – не найбільший:** Хоча 'Organic Search' приносить найбільше *грошей*, наш аналіз конверсії (CR) показав, що **'Social Search'**  є **найефективнішим** каналом у перетворенні сесій на покупки (**CR 9.73%**). Усі інші канали демонструють практично однаковий CR (≈9.58%).
#
# 2.  **Реєстрація не впливає на середній чек:** За допомогою **тесту Манна-Вітні** ми довели, що **немає статистично значущої різниці** (P-value = 0.27) у *сумі індивідуальної покупки* (чеку)  між зареєстрованими (1) та незареєстрованими (0) користувачами. Хоча зареєстровані купують *частіше*, їхній середній чек такий самий.
#
# 3.  **Платформа не впливає на середній чек:** Ми спростували гіпотезу, що користувачі Apple  витрачають більше. Середній чек є практично **однаковим** для всіх операційних систем (Android, Windows, iOS, Mac) і коливається в вузькому діапазоні 930-980.
#
# **Підсумкова рекомендація:** Маркетингові зусилля мають бути максимально сконцентровані на **ринку США** під час **сезонних піків** (листопад-грудень), з особливим акцентом на просуванні **"великої трійки" товарів** (дивани, крісла, ліжка) через канали **Desktop Search** (Organic та Paid).

# %% [markdown]
# # Підключення до БД та SQL запит

# %%
# !pip install --upgrade google-cloud-bigquery

# (UA) Імпортуємо необхідні бібліотеки для роботи з даними та виконання статистичних тестів
# (ENG) Import required libraries for data manipulation and statistical tests
from google.colab import auth
from google.cloud import bigquery
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr, shapiro, mannwhitneyu, f_oneway, wilcoxon, kruskal

# (UA) Аутентифікація користувача для доступу до Google Cloud
# (ENG) Authenticate user to access Google Cloud
auth.authenticate_user()

# (UA) Створення клієнта для доступу до BigQuery
# (ENG) Create a client for accessing BigQuery
client = bigquery.Client(project="data-analytics-mate")

# (UA) SQL-запит для вибірки даних з бази даних
# (ENG) SQL query to fetch data from the database
query = """
SELECT
  s.date AS date,
  s.ga_session_id AS session_id,
  sp.continent AS continent,
  sp.country AS country,
  sp.device AS device,
  sp.browser AS browser,
  sp.mobile_model_name AS device_model_name,
  sp.operating_system AS operating_system,
  sp.language AS browser_language,
  sp.channel AS traffic_source_information,
  acc.is_verified AS account_verified,
  acc.is_unsubscribed AS account_unsubscribed,
  p.category AS product_category,
  p.name AS product_name,
  p.price AS price,
  p.short_description AS short_product_description
FROM `DA.session` s
LEFT JOIN `DA.account_session` acs
      ON acs.ga_session_id = s.ga_session_id
LEFT JOIN `DA.account` acc
      ON acc.id = acs.account_id
LEFT JOIN `DA.session_params` sp
      ON s.ga_session_id = sp.ga_session_id
LEFT JOIN `DA.order` o
      ON sp.ga_session_id = o.ga_session_id
LEFT JOIN `DA.product` p
      ON o.item_id = p.item_id
ORDER BY s.date
"""

# (UA) Виконання SQL-запиту до BigQuery та отримання результатів
# (ENG) Execute SQL query in BigQuery and fetch the results
query_job = client.query(query)  # Виконання SQL-запиту
results = query_job.result()  # Очікування завершення запиту

# (UA) Перетворення результатів запиту на DataFrame для подальшого аналізу
# (ENG) Convert the query results to a DataFrame for further analysis
df = results.to_dataframe()

# (UA) Виведення DataFrame для перевірки результатів
# (ENG) Display DataFrame to check the results
df
# Out:
# ...
#               date  session_id continent         country   device  browser  \
# 0       2020-11-01    65223751  Americas   United States   mobile   Chrome
# 1       2020-11-01  7115337200    Europe  United Kingdom  desktop   Chrome
# 2       2020-11-01  3978035233    Europe          Norway   mobile   Chrome
# 3       2020-11-01  9648986282    Africa         Nigeria   mobile   Chrome
# 4       2020-11-01  4393441533      Asia           China  desktop   Chrome
# ...            ...         ...       ...             ...      ...      ...
# 349540  2021-01-31  5756982967    Europe         Ukraine  desktop  Firefox
# 349541  2021-01-31   464560636  Americas   United States  desktop     Edge
# 349542  2021-01-31  6336117447  Americas   United States  desktop   Chrome
# 349543  2021-01-31  4958826563      Asia           India   mobile   Safari
# 349544  2021-01-31  7058940865    Europe          Norway  desktop     Edge
#
#        device_model_name operating_system browser_language  \
# ...

# %% [markdown]
# ## Встановлюємо стиль для графіків

# %%
# (UA) Встановлюємо стиль з багатоколірною палітрою
# (ENG) Set a style with a multi-color palette
sns.set_theme(
    style="whitegrid",
    palette="viridis"
)

print("Глобальну палітру оновлено на 'viridis'.")
# Out:
# Глобальну палітру оновлено на 'viridis'.

# %% [markdown]
# # Опис датасету

# %%
# (UA) Отримуємо загальну інформацію з дата сету
# (ENG) We get general information from the data set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349545 entries, 0 to 349544
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   date                        349545 non-null  dbdate
#  1   session_id                  349545 non-null  Int64
#  2   continent                   349545 non-null  object
#  3   country                     349545 non-null  object
#  4   device                      349545 non-null  object
#  5   browser                     349545 non-null  object
#  6   device_model_name           349545 non-null  object
#  7   operating_system            349545 non-null  object
#  8   browser_language            235279 non-null  object
#  9   traffic_source_information  349545 non-null  object
#  10  account_verified            27945 non-null   Int64
#  11  account_unsubscribed        27945 non-null   Int64
#  12  product_category            33538 non-null   object
# ...

# %%
# (UA) Знаходимо кількість унікальніх сессій
# Finding the number of unique sessions
df['session_id'].nunique()
# Out:
# 349545

# %%
# (UA) Отримуємо період часу який розглядається в дата фреймі
# (ENG) We get the time period considered in the date frame
print(f"Період даних з {df['date'].min()} по {df['date'].max()}")
# Out:
# Період даних з 2020-11-01 по 2021-01-31

# %% [markdown]
# # Аналіз продажів

# %% [markdown]
# ## Топ - 3 континенти за найбільшими продажами

# %%
# (UA) Топ-3 континенти за сумою продажів:
# (ENG) Top 3 continents by sales:
top_3_sales_sum = df.groupby("continent")["price"].sum().sort_values(ascending=False).head(3)

# (UA) Топ-3 континенти за кількістю замовлень:
# (ENG) Top 3 continents by number of orders:
top_3_sales_count = df.groupby("continent")["price"].count().sort_values(ascending=False).head(3)

# (UA)  Створюємо візуалізацію
# (ENG)  Create the visualization

# (UA) Створюємо фігуру з двома графіками
# (ENG) Creating a shape with two graphs
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# (UA)Графік 1: Сума продажів
# (ENG) Chart 1: Sales Amount
sns.barplot(x=top_3_sales_sum.index, y=top_3_sales_sum.values, ax=ax1)
ax1.set_title('Топ-3 континенти за сумою продажів', fontsize=14)
ax1.set_xlabel('Континент', fontsize=12)
ax1.set_ylabel('Загальна сума продажів', fontsize=12)

# (UA) Графік 2: Кількість замовлень
# (ENG) Chart 2: Number of orders
sns.barplot(x=top_3_sales_count.index, y=top_3_sales_count.values, ax=ax2)
ax2.set_title('Топ-3 континенти за кількістю замовлень', fontsize=14)
ax2.set_xlabel('Континент', fontsize=12)
ax2.set_ylabel('Кількість замовлень', fontsize=12)

# (UA) Покращуємо читабельність та зберігаємо
# (ENG) Improve readability and save
plt.tight_layout()
plt.savefig('continent_comparison_styled.png')

print("Топ-3 континенти за сумою продажів:")
print(top_3_sales_sum)
print("Топ-3 континенти за кількістю замовлень:")
print(top_3_sales_count)
# Out:
# Топ-3 континенти за сумою продажів:
# continent
# Americas    17665280.0
# Asia         7601298.3
# Europe       5934624.2
# Name: price, dtype: float64
# Топ-3 континенти за кількістю замовлень:
# continent
# Americas    18553
# Asia         7950
# Europe       6261
# Name: price, dtype: int64

# %% [markdown]
# ## Топ - 5 країн за найбільшими продажами

# %%
# Топ-5 країн за СУМОЮ продажів
top_5_countries_sum = df.groupby("country")["price"].sum().sort_values(ascending=False).head(5)

# Топ-5 країн за КІЛЬКІСТЮ замовлень
top_5_countries_count = df.groupby("country")["price"].count().sort_values(ascending=False).head(5)

# (UA)  Створюємо візуалізацію
# (ENG)  Create the visualization
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 7))

# Графік 1: Сума продажів
sns.barplot(
    x=top_5_countries_sum.index,
    y=top_5_countries_sum.values,
    ax=ax1
)
ax1.set_title('Топ-5 країн за СУМОЮ продажів', fontsize=14)
ax1.set_xlabel('Країна', fontsize=12)
ax1.set_ylabel('Загальна сума продажів', fontsize=12)

# (UA) Додаємо нахил для довгих назв
# (ENG) Add rotation for long labels
ax1.tick_params(axis='x', rotation=45)

# Графік 2: Кількість замовлень
sns.barplot(
    x=top_5_countries_count.index,
    y=top_5_countries_count.values,
    ax=ax2
)
ax2.set_title('Топ-5 країн за КІЛЬКІСТЮ замовлень', fontsize=14)
ax2.set_xlabel('Країна', fontsize=12)
ax2.set_ylabel('Кількість замовлень', fontsize=12)
ax2.tick_params(axis='x', rotation=45)

# (UA) Покращуємо читабельність та зберігаємо
# (ENG) Improve readability and save
plt.tight_layout()
plt.savefig('country_comparison.png')

print("Топ-5 країн за СУМОЮ продажів:")
print(top_5_countries_sum)
print("\nТоп-5 країн за КІЛЬКІСТЮ замовлень:")
print(top_5_countries_count)
print("\nГрафік 'country_comparison.png' збережено.")
# Out:
# Топ-5 країн за СУМОЮ продажів:
# country
# United States     13943553.9
# India              2809762.0
# Canada             2437921.0
# United Kingdom      938317.9
# France              710692.8
# Name: price, dtype: float64
#
# Топ-5 країн за КІЛЬКІСТЮ замовлень:
# country
# United States     14673
# India              3029
# Canada             2560
# United Kingdom     1029
# France              678
# Name: price, dtype: int64
#
# Графік 'country_comparison.png' збережено.

# %% [markdown]
# ## Топ-10 категорій товарів за загальною сумою продажів

# %%
# (UA) Групуємо за категоріями, сумуємо ціни, сортуємо за спаданням і беремо топ-10
# (ENG) We group by categories, sum prices, sort in descending order and take the top 10
top_10_category_sales = df.groupby("product_category")["price"].sum().sort_values(ascending=False).head(10)
print(top_10_category_sales)
# Out:
# product_category
# Sofas & armchairs                   8388254.5
# Chairs                              6147748.8
# Beds                                4919725.0
# Bookcases & shelving units          3640818.1
# Cabinets & cupboards                2336499.5
# Outdoor furniture                   2142222.2
# Tables & desks                      1790307.5
# Chests of drawers & drawer units     906562.5
# Bar furniture                        735503.0
# Children's furniture                 467697.0
# Name: price, dtype: float64

# %%
# (UA) Топ 10 категорій за сумою продажів
# (ENG) Top 10 categories by sales amount
top_10_category_sales = df.groupby("product_category")["price"].sum().sort_values(ascending=False).head(10)

# (UA)  Створюємо візуалізацію
# (ENG)  Create the visualization
plt.figure(figsize=(12, 7)) # Робимо графік трохи більшим для 10 категорій
sns.barplot(
    x=top_10_category_sales.values,
    y=top_10_category_sales.index
)

# (UA) Додаємо назви та підписи
# (ENG) Add titles and labels
plt.title('Топ-10 категорій товарів за сумою продажів', fontsize=16)
plt.xlabel('Загальна сума продажів', fontsize=12)
plt.ylabel('Категорія товару', fontsize=12)

# (UA) Зберігаємо файл
# (ENG) Save the file
plt.tight_layout() # Для кращої читабельності
plt.savefig('top_10_categories_sales.png')

# %% [markdown]
# ## Топ-10 категорій товарів у країні з найбільшими продажами, чи відрізняється ситуація від загальної?

# %%
# (UA) Фільтруємо DataFrame, щоб отримати лише рядки, де країна - США
# (ENG) Filter the DataFrame to get only rows where the country is USA
df_us = df[df['country'] == 'United States']

# (UA) Перевіряємо, що вийшло
# (ENG) Check the result
print(f"Загальна кількість сесій: {len(df)}")
print(f"Кількість сесій у США: {len(df_us)}")
# Out:
# Загальна кількість сесій: 349545
# Кількість сесій у США: 153470

# %%
top_10_sales_US = df_us.groupby("product_category")["price"].sum().sort_values(ascending = False).head(10)
print("Топ-10 категорії за СУМОЮ продажів в розрізі США:")
print(top_10_sales_US)
# Out:
# Топ-10 категорії за СУМОЮ продажів в розрізі США:
# product_category
# Sofas & armchairs                   3707144.5
# Chairs                              2619773.8
# Beds                                2213058.0
# Bookcases & shelving units          1567606.9
# Cabinets & cupboards                 994545.5
# Outdoor furniture                    929245.2
# Tables & desks                       777865.0
# Chests of drawers & drawer units     382388.0
# Bar furniture                        330805.0
# Children's furniture                 207575.0
# Name: price, dtype: float64

# %%
# (UA)  Створюємо фігуру
# (ENG)  Create the figure
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 8))

# (UA)  Малюємо графіки
# (ENG)  Draw the plots

# Графік 1: Загальний Топ-10
sns.barplot(
    x=top_10_category_sales.values,
    y=top_10_category_sales.index,
    ax=ax1
)
ax1.set_title('Загальний Топ-10 категорій', fontsize=14)
ax1.set_xlabel('Загальна сума продажів', fontsize=12)
ax1.set_ylabel('Категорія', fontsize=12)

# Графік 2: Топ-10 для США
sns.barplot(
    x=top_10_sales_US.values,
    y=top_10_sales_US.index,
    ax=ax2
)
ax2.set_title('Топ-10 категорій (США)', fontsize=14)
ax2.set_xlabel('Загальна сума продажів', fontsize=12)
ax2.set_ylabel('') # Прибираємо дублюючу назву осі

# (UA) 5. Зберігаємо
# (ENG) 5. Save
plt.tight_layout()
plt.savefig('category_comparison.png')

print("Графік 'category_comparison.png' збережено.")
print("\nЗагальний Топ-10:")
print(top_10_category_sales.index.to_list())
print("\nТоп-10 для США:")
print(top_10_sales_US.index.to_list())
# Out:
# Графік 'category_comparison.png' збережено.
#
# Загальний Топ-10:
# ['Sofas & armchairs', 'Chairs', 'Beds', 'Bookcases & shelving units', 'Cabinets & cupboards', 'Outdoor furniture', 'Tables & desks', 'Chests of drawers & drawer units', 'Bar furniture', "Children's furniture"]
#
# Топ-10 для США:
# ['Sofas & armchairs', 'Chairs', 'Beds', 'Bookcases & shelving units', 'Cabinets & cupboards', 'Outdoor furniture', 'Tables & desks', 'Chests of drawers & drawer units', 'Bar furniture', "Children's furniture"]

# %% [markdown]
# ##  Продажі у розрізі типів та моделей девайсів (у % від загальних продажів)

# %%
# (UA)  Розраховуємо "частину" (сума за девайсами)
# (ENG)  Calculate the "part" (sum by device)
sales_grouped_device = df.groupby("device")["price"].sum()

# (UA)  Розраховуємо "ціле" (загальна сума)
# (ENG)  Calculate the "whole" (total sum)
total_sales = df['price'].sum()

# (UA)  Ділимо та множимо на 100, щоб отримати %
# (ENG)  Divide and multiply by 100 to get %
device_sales_percent = (sales_grouped_device / total_sales) * 100

# (UA)  Сортуємо для кращої читабельності
# (ENG)  Sort for better readability
device_sales_percent = device_sales_percent.sort_values(ascending=False)

print("Продажі за типом девайсу (у % від загальних):")
print(device_sales_percent.round(2)) # для охайного вигляду(кількість значень після коми)

# (UA) Створюємо Горизонтальну стовпчасту діаграму
# (ENG) Create the Horizontal bar chart
plt.figure(figsize=(10, 6))

sns.barplot(
    x=device_sales_percent.values,
    y=device_sales_percent.index
)

# (UA) Оновлюємо назви
# (ENG) Update the titles
plt.title('Розподіл продажів за типом девайсів (%)', fontsize=14)
plt.xlabel('Відсоток від загальних продажів (%)', fontsize=12)
plt.ylabel('Тип девайсу', fontsize=12)

plt.tight_layout()
# Out:
# Продажі за типом девайсу (у % від загальних):
# device
# desktop    59.00
# mobile     38.73
# tablet      2.26
# Name: price, dtype: float64

# %%
# (UA)  Створюємо список браузерів, які треба виключити
# (ENG)  Create a list of browsers to exclude
browsers = ['Chrome', 'Safari', 'Firefox', 'Edge', 'Opera', '<Other>']

# (UA)  Фільтруємо дані
# (ENG)  Filter the data
df_devices = df[~df['device_model_name'].isin(browsers)]

# (UA)  Розраховуємо "частину" з чистого DataFrame
# (ENG)  Calculate the "part" from the clean DataFrame
sales_grouped_device_model = df_devices.groupby("device_model_name")["price"].sum()

# (UA)  Розраховуємо "ціле" з того ж чистого DataFrame
# (ENG)  Calculate the "whole" from the same clean DataFrame
total_sales_devices_only = df_devices['price'].sum()

# (UA)  Ділимо та множимо на 100
# (ENG)  Divide and multiply by 100
device_model_sales_percent = (sales_grouped_device_model / total_sales_devices_only) * 100

# (UA)  Сортуємо
# (ENG)  Sort
device_model_sales_percent = device_model_sales_percent.sort_values(ascending=False)

print("Продажі моделей девайсів (у % від відфільтрованих):")
print(device_model_sales_percent.round(2))

# (UA) Створюємо Горизонтальну стовпчасту діаграму
# (ENG)  Create the Horizontal bar chart
plt.figure(figsize=(10, 6)) # (UA) Робимо її ширшою, ніж вищою

sns.barplot(
    x=device_model_sales_percent.values,
    y=device_model_sales_percent.index
)

# (UA) Оновлюємо назви
# (ENG) Update the titles
plt.title('Розподіл продажів за моделями девайсів (%)', fontsize=14)
plt.xlabel('Відсоток від загальних продажів (%)', fontsize=12)
plt.ylabel('Модель девайсу', fontsize=12)

# (UA) Зберігаємо
# (ENG) Save
plt.tight_layout()
plt.savefig('device_model_sales_barchart.png')

print("Графік 'device_model_sales_barchart.png' збережено.")
# Out:
# Продажі моделей девайсів (у % від відфільтрованих):
# device_model_name
# iPhone        71.92
# ChromeBook    20.50
# iPad           5.03
# Pixel 4 XL     1.32
# Pixel 3        1.22
# Name: price, dtype: float64
# Графік 'device_model_sales_barchart.png' збережено.

# %% [markdown]
# ## Продажі за джерелами трафіку (у % від загальних продажів)

# %%
# (UA) Код для розрахунку даних
# (ENG) Code for data calculation
sales_trafic = df.groupby("traffic_source_information")["price"].sum()
total_sales_trafic = df["price"].sum()
trafic_percent = (sales_trafic / total_sales_trafic) * 100
trafic_percent = trafic_percent.sort_values(ascending=False)

print("Продажі за джерелом трафіку (%):")
print(trafic_percent.round(2))

# (UA) Створюємо фігуру
# (ENG) Create the figure
plt.figure(figsize=(10, 7))

# (UA) Код для візуалізації
# (ENG) Code for visualization
sns.barplot(
    x=trafic_percent.values,
    y=trafic_percent.index
)
plt.title('Продажі за джерелом трафіку (%)', fontsize=14)
plt.xlabel('Відсоток від загальних продажів (%)', fontsize=12)
plt.ylabel('Джерело трафіку', fontsize=12)

# (UA) Зберігаємо
# (ENG) Save
plt.tight_layout()
plt.savefig('traffic_source_sales_barchart.png')

print("\nГрафік 'traffic_source_sales_barchart.png' збережено.")
# Out:
# Продажі за джерелом трафіку (%):
# traffic_source_information
# Organic Search    35.76
# Paid Search       26.62
# Direct            23.44
# Social Search      7.92
# Undefined          6.26
# Name: price, dtype: float64
#
# Графік 'traffic_source_sales_barchart.png' збережено.

# %% [markdown]
# ## Відсоток зареєстрованих користувачів який підтвердив свою електронну адресу

# %%
# (UA) Фільтруємо лише зареєстрованих (де 'account_verified' не NULL)
# (ENG) Filter for registered users only (where 'account_verified' is not NULL)
df_registered = df[df['account_verified'].notna()]

# (UA) Знаходимо середнє значення (0 = ні, 1 = так)
# (ENG) Find the mean (0 = no, 1 = yes)
percent_verified = df_registered['account_verified'].mean()

print(f"Відсоток підтверджених: {percent_verified * 100:.1f}%")
# Out:
# Відсоток підтверджених: 71.7%

# %% [markdown]
# ## Відсоток зареєстрованих користувачів які відписався від розсилки

# %%
# (UA) Використовуємо той самий DataFrame 'df_registered'
# (ENG) Use the same 'df_registered' DataFrame

# (UA) Знаходимо середнє значення (0 = ні, 1 = так)
# (ENG) Find the mean (0 = no, 1 = yes)
percent_unsubscribed = df_registered['account_unsubscribed'].mean()

print(f"Відсоток тих, хто відписався: {percent_unsubscribed * 100:.1f}%")
# Out:
# Відсоток тих, хто відписався: 16.9%

# %% [markdown]
# ## Чи відрізняється поведінка (у плані продажів) тих, хто відписався від розсилки та тих, хто досі підписаний?

# %% [markdown]
# Висновок: Поведінка підписаних vs. відписаних
#
# * Кількість покупок (count): Користувачі, які залишилися підписаними, зробили набагато більше покупок (2334), ніж ті, хто відписався (447).
#
# * Середній чек (mean): Користувачі, які відписалися, витрачають в середньому трохи більше грошей за одну покупку (965.82), ніж підписані (921.50). Медіана (50%) також вища (450.00 проти 395.00).
#
# Підсумок: Хоча підписані користувачі купують набагато частіше, ті, хто відписався, демонструють трохи вищий середній чек за покупку.

# %%
# (UA) Створюємо дві групи
# (ENG) Create the two groups
df_unsubscribed = df_registered[df_registered['account_unsubscribed'] == 1]
df_subscribed = df_registered[df_registered['account_unsubscribed'] == 0]

print("--- Статистика для тих, хто Відписався ---")
# (UA) Використовуємо .describe() для колонки price
# (ENG) Use .describe() on the price column
print(df_unsubscribed['price'].describe())

print("\n--- Статистика для тих, хто Залишився підписаним ---")
# (UA) Робимо те саме для другої групи
# (ENG) Do the same for the second group
print(df_subscribed['price'].describe())
# Out:
# --- Статистика для тих, хто Відписався ---
# count     447.000000
# mean      965.820134
# std      1298.176986
# min         3.000000
# 25%       175.000000
# 50%       450.000000
# 75%      1297.500000
# max      8900.000000
# Name: price, dtype: float64
#
# --- Статистика для тих, хто Залишився підписаним ---
# count    2334.000000
# mean      921.506812
# std      1323.918182
# min         3.000000
# 25%       149.000000
# 50%       395.000000
# 75%      1100.000000
# max      8900.000000
# Name: price, dtype: float64

# %% [markdown]
# ## В яких країнах найбільше зареєстрованих користувачів?

# %% [markdown]
# Топ 3 країни в яких найбільше зареєстрованих користувачів
# 1. United States
# 2. India
# 3. Canada

# %%
# (UA) Готуємо дані
# (ENG) Prepare the data
df_registered = df[df['account_verified'].notna()]
grouped_country_registered = df_registered.groupby("country")["session_id"].count().sort_values(ascending=False).head(10)

print("Топ-10 країн за кількістю зареєстрованих користувачів:")
print(grouped_country_registered)

# (UA) Створюємо фігуру
# (ENG) Create the figure
plt.figure(figsize=(10, 8))

sns.barplot(
    x=grouped_country_registered.values,
    y=grouped_country_registered.index
)
plt.title('Топ-10 країн за кількістю зареєстрованих користувачів', fontsize=14)
plt.xlabel('Кількість зареєстрованих сесій', fontsize=12)
plt.ylabel('Країна', fontsize=12)

# (UA) Зберігаємо
# (ENG) Save
plt.tight_layout()
plt.savefig('top_10_countries_registered_users.png')

print("\nГрафік 'top_10_countries_registered_users.png' збережено.")
# Out:
# Топ-10 країн за кількістю зареєстрованих користувачів:
# country
# United States     12384
# India              2687
# Canada             2067
# United Kingdom      859
# France              553
# Spain               536
# Taiwan              500
# China               490
# Germany             490
# Italy               386
# Name: session_id, dtype: Int64
#
# Графік 'top_10_countries_registered_users.png' збережено.

# %% [markdown]
# ## Чи збігається популярність браузера з обсягом продажів?

# %% [markdown]
# Популярність браузера прямо відповідає його прибутковості.
#
# Ось що ми бачимо:
#
# Домінування Chrome: Браузер Chrome є абсолютним лідером з величезним відривом як за сумою продажів (понад 20 мільйонів), так і за кількістю сесій (понад 200 тисяч).
#
# Чітке друге місце: Safari посідає впевнене друге місце в обох категоріях, але значно відстає від Chrome.
#
# Ідентичні списки: Найголовніше те, що порядок браузерів у лівому списку (за грошима ) практично повністю збігається з порядком у правому списку (за кількістю ).
#
# Висновок: Немає жодних сюрпризів. Браузери, якими користується найбільше людей, приносять найбільше грошей.

# %%
# (UA) Готуємо дані
# (ENG) Prepare the data
grouped_browser_price = df.groupby('browser')['price'].sum().sort_values(ascending=False).head(10)
group_session_browser = df.groupby('browser')['session_id'].count().sort_values(ascending=False).head(10)

# (UA) Створюємо фігуру з двома графіками
# (ENG) Create the figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 8))

# (UA) Графік 1: Сума продажів
# (ENG) Plot 1: Sum of Sales
sns.barplot(
    x=grouped_browser_price.values,
    y=grouped_browser_price.index,
    ax=ax1
)
ax1.set_title('Топ-10 браузерів за сумою продажів', fontsize=14)
ax1.set_xlabel('Загальна сума продажів', fontsize=12)
ax1.set_ylabel('Браузер', fontsize=12)

# (UA) Графік 2: Кількість сесій
# (ENG) Plot 2: Count of Sessions
sns.barplot(
    x=group_session_browser.values,
    y=group_session_browser.index,
    ax=ax2
)
ax2.set_title('Топ-10 браузерів за кілкістю сесій', fontsize=14)
ax2.set_xlabel('Загальна кількість сесій', fontsize=12)
ax2.set_ylabel('') # (UA) Прибираємо дублюючу назву осі

# (UA) 6. Зберігаємо
# (ENG) 6. Save
plt.tight_layout()
plt.savefig('browser_sales_vs_sessions_barchart.png')

print("Графік 'browser_sales_vs_sessions_barchart.png' збережено.")
# Out:
# Графік 'browser_sales_vs_sessions_barchart.png' збережено.

# %% [markdown]
# ## Чи витрачають користувачі Apple (iOS/Mac) в середньому більше, ніж користувачі Android/Windows?

# %% [markdown]
# Виходячи з цих даних, наша гіпотеза про те, що користувачі Apple (Macintosh/iOS) витрачають більше, не підтвердилася.
#
# Android (978.25) та Windows (976.63) насправді мають трохи вищий середній чек, ніж Macintosh (973.55) та iOS (948.74).
#
# Однак найважливіший висновок - всі значення знаходяться в діапазоні 930-980. Це свідчить про те, що операційна система, не має суттєвого впливу на середню суму покупки.

# %%
grouped_operating_system = df.groupby('operating_system')['price'].mean().sort_values(ascending = False)
print(grouped_operating_system)
# Out:
# operating_system
# Android      978.255645
# Windows      976.639887
# Macintosh    973.558997
# iOS          948.743918
# Web          944.152352
# <Other>      932.602948
# Name: price, dtype: float64

# %% [markdown]
# # Аналіз динаміки продажів

# %% [markdown]
# ## Загальні продажі за кожну дату, чи спостерігається сезонність продажів?

# %% [markdown]
# Дивлячись на ваш лінійний графік , ми можемо зробити чіткий висновок.
#
# Ось що ми бачимо:
#
# 1. Чіткі святкові піки: На графіку є два величезних піки продажів.
#
# * Перший, найбільший, припадає на кінець листопада (приблизно 24-27 листопада). Це майже напевно "Чорна п'ятниця" / "Кіберпонеділок".
#
# * Другий великий пік — наприкінці грудня (приблизно 21-25 грудня), що чітко відповідає фінальному ажіотажу перед Різдвом.
#
# 2. Спади після свят: Одразу після цих піків (особливо після різдвяного) видно різкі падіння продажів, що є типовою поведінкою.
#
# 3. "Затишшя" у січні: Продажі в січні виглядають загалом значно нижчими та стабільнішими , ніж у пікові місяці листопад і грудень.
#
# **Висновок**: Ми спостерігаємо дуже сильну сезонність, яка повністю прив'язана до головних зимових свят і розпродажів.

# %%
# (UA) Готуємо дані
# (ENG) Prepare the data
grouped_date_sum = df.groupby('date')['price'].sum()

# (UA) Створюємо фігуру
# (ENG) Create the figure
plt.figure(figsize=(14, 6))

# (UA) Створюємо лінійний графік
# (ENG) Create the line plot
sns.lineplot(
    x=grouped_date_sum.index,
    y=grouped_date_sum.values
)

# (UA) Додаємо назви та покращуємо читабельність
# (ENG)  Add titles and improve readability
plt.title('Загальна динаміка продажів за датою', fontsize=16)
plt.xlabel('Дата', fontsize=12)
plt.ylabel('Загальна сума продажів', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

# (UA) Зберігаємо
# (ENG) Save
plt.savefig('daily_sales_dynamics.png')

print("Графік 'daily_sales_dynamics.png' збережено.")
# Out:
# Графік 'daily_sales_dynamics.png' збережено.

# %% [markdown]
# ## Динаміка продажів

# %% [markdown]
# **Загальний висновок по динаміці**
# * Спільний патерн: Усі графіки (загальний, за континентами, трафіком і девайсами) показують однаковий загальний тренд. Динаміка продажів повністю визначається сезонністю, з чіткими піками  наприкінці листопада (Чорна п'ятниця) та наприкінці грудня (Різдво).
#
# * Ключові сегменти: Графік динаміки продажіву розрізі типів девайсів  чітко показує, що, хоча загальний патерн однаковий, основний обсяг доходу генерують два сегменти: desktop та mobile. Лінія 'tablet' лежить майже на нулі.

# %% [markdown]
# ### Динаміка продажів в Америці, Азії та Європі

# %%
# (UA) Фільтруємо лише 3 континенти
# (ENG) Filter for only 3 continents
df_continent = df[df['continent'].isin(['Americas', 'Asia', 'Europe'])]

# (UA) Групуємо
# (ENG) Group
group_continent = df_continent.groupby(['date', 'continent'])['price'].sum()

# (UA) Перетворюємо на DataFrame за допомогою .reset_index()
# (ENG) Convert to a DataFrame using .reset_index()
sales_by_continent_df = group_continent.reset_index()

# (UA) Створюємо фігуру
# (ENG) Create the figure
plt.figure(figsize=(14, 6))

# (UA) Малюємо лінійний графік з різними кольорами (hue)
# (ENG) Draw the line plot with different colors (hue)
sns.lineplot(
    data=sales_by_continent_df,
    x='date',
    y='price',
    hue='continent'            # (UA) Це автоматично створить кольорові лінії
)

plt.title('Динаміка продажів за континентами', fontsize=16)
plt.xlabel('Дата', fontsize=12)
plt.ylabel('Загальна сума продажів', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

# (UA) Зберігаємо
# (ENG) Save
plt.savefig('continent_sales_dynamics.png')

print("Графік 'continent_sales_dynamics.png' збережено.")
# Out:
# Графік 'continent_sales_dynamics.png' збережено.

# %% [markdown]
# ### Динаміка продажів у розрізі каналів трафіку

# %%
# (UA) Групуємо
# (ENG) Group
group_traffic = df.groupby(['date', 'traffic_source_information'])['price'].sum()

# (UA) Перетворюємо на DataFrame за допомогою .reset_index()
# (ENG) Convert to a DataFrame using .reset_index()
sales_by_traffic_df = group_traffic.reset_index()

# (UA) Створюємо фігуру
# (ENG) Create the figure
plt.figure(figsize=(14, 6))

# (UA) Малюємо лінійний графік з різними кольорами (hue)
# (ENG) Draw the line plot with different colors (hue)
sns.lineplot(
    data=sales_by_traffic_df,
    x='date',
    y='price',
    hue='traffic_source_information'            # (UA) Це автоматично створить кольорові лінії
)

plt.title('Динаміка продажів за каналами трафіку', fontsize=16)
plt.xlabel('Дата', fontsize=12)
plt.ylabel('Загальна сума продажів', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

# (UA) Зберігаємо
# (ENG) Save
plt.savefig('sales_by_traffic_df.png')

print("Графік 'sales_by_traffic_df.png' збережено.")
# Out:
# Графік 'sales_by_traffic_df.png' збережено.

# %% [markdown]
# ### Динаміка продажів у розрізі типів девайсів

# %%
# (UA) Групуємо
# (ENG) Group
group_device = df.groupby(['date', 'device'])['price'].sum()

# (UA) Перетворюємо на DataFrame за допомогою .reset_index()
# (ENG) Convert to a DataFrame using .reset_index()
sales_by_device_df = group_device.reset_index()

# (UA) Створюємо фігуру
# (ENG) Create the figure
plt.figure(figsize=(14, 6))

# (UA) Малюємо лінійний графік з різними кольорами (hue)
# (ENG) Draw the line plot with different colors (hue)
sns.lineplot(
    data=sales_by_device_df,
    x='date',
    y='price',
    hue='device'            # (UA) Це автоматично створить кольорові лінії
)

plt.title('Динаміка продажів за типом девайсу', fontsize=16)
plt.xlabel('Дата', fontsize=12)
plt.ylabel('Загальна сума продажів', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

# (UA) Зберігаємо
# (ENG) Save
plt.savefig('sales_by_device_df.png')

print("Графік 'sales_by_device_df.png' збережено.")
# Out:
# Графік 'sales_by_device_df.png' збережено.

# %% [markdown]
# # Зведені таблиці

# %% [markdown]
# ##  Кількість сесій у розрізі каналів трафіку та типів девайсів

# %%
# (UA) Створюємо зведену таблицю
# (ENG) Create the pivot table
pivot_table_sessions = pd.pivot_table(
    df,
    values='session_id',
    index='traffic_source_information',
    columns='device',
    aggfunc='count'
)

# (UA) Виводимо результат
# (ENG) Display the result
print("Зведена таблиця: Сесії за трафіком та девайсом")
print(pivot_table_sessions)
# Out:
# Зведена таблиця: Сесії за трафіком та девайсом
# device                      desktop  mobile  tablet
# traffic_source_information
# Direct                        47825   31745    1812
# Organic Search                72622   49014    2789
# Paid Search                   55167   37034    2140
# Social Search                 16288   10988     638
# Undefined                     12527    8486     470

# %% [markdown]
# ## Загальні продажі за категоріями товарів (топ-10 категорій) у різних країнах (топ-5 країн)

# %%
# (UA) 1. Створюємо списки (як ми вже зробили)
# (ENG) 1. Create the lists (as we already did)
top_5_countries_list = df.groupby('country')['price'].sum().sort_values(ascending=False).head(5).index
top_10_categories_list = df.groupby('product_category')['price'].sum().sort_values(ascending=False).head(10).index

# (UA) 2. Створюємо дві окремі умови
# (ENG) 2. Create two separate conditions
condition_1_country = df['country'].isin(top_5_countries_list)
condition_2_category = df['product_category'].isin(top_10_categories_list)

# (UA) 3. Об'єднуємо умови за допомогою '&' (ТА) і фільтруємо ОДИН РАЗ
# (ENG) 3. Combine conditions with '&' (AND) and filter ONCE
df_top_sales = df[condition_1_country & condition_2_category]

pivot_table = pd.pivot_table(
    df_top_sales,
    values='price',
    index='product_category',
    columns='country',
    aggfunc='sum'
)
print(pivot_table)
# Out:
# country                             Canada    France     India  \
# product_category
# Bar furniture                      51724.0   11199.0   57657.0
# Beds                              354772.0  116414.0  358319.5
# Bookcases & shelving units        278981.9   73830.0  364507.4
# Cabinets & cupboards              181802.0   59101.5  191888.0
# Chairs                            417740.8  134029.4  544309.2
# Chests of drawers & drawer units   71952.0   21544.5   73111.0
# Children's furniture               30264.0   14258.0   39177.0
# Outdoor furniture                 185322.8   40486.4  162289.4
# Sofas & armchairs                 692427.5  187735.0  788430.0
# Tables & desks                    132678.0   42299.0  186157.5
#
# country                           United Kingdom  United States
# product_category
# Bar furniture                            22103.0       330805.0
# Beds                                    133816.0      2213058.0
# ...

# %% [markdown]
# ## Середній чек  у розрізі континентів та типів девайсів

# %%
# (UA) Фільтруємо дані
# (ENG) Data filtering
browsers = ['Chrome', 'Safari', 'Firefox', 'Edge', 'Opera']
df_devices = df[~df['device_model_name'].isin(browsers)]
# (UA) Створюємо зведену таблицю
# (ENG) Create the pivot table
pivot_table = pd.pivot_table(
    df_devices,
    values='price',
    index='device_model_name',
    columns='continent',
    aggfunc='mean'
)
# (UA) Виводимо результат
# (ENG) Display the result
print("Зведена таблиця: Середній чек у розрізі континентів та девайсів")
print(pivot_table)
# Out:
# Зведена таблиця: Середній чек у розрізі континентів та девайсів
# continent            (not set)       Africa     Americas         Asia  \
# device_model_name
# <Other>            1046.900000  1090.268116   964.410840   994.627377
# ChromeBook          882.200000  1508.875000   976.799809   940.603935
# Pixel 3                    NaN          NaN   945.267273  1421.000000
# Pixel 4 XL                 NaN          NaN  1038.135714  1073.414815
# iPad                 70.000000   414.200000  1001.534800   949.622642
# iPhone             1124.166667   776.728750   914.384878   979.186613
#
# continent               Europe      Oceania
# device_model_name
# <Other>             897.932610   960.241935
# ChromeBook         1003.393429   808.732143
# Pixel 3             741.340000  2196.000000
# Pixel 4 XL          831.800000          NaN
# iPad               1007.747191  1196.000000
# iPhone              989.351339   776.939655

# %% [markdown]
# ## Загальна сума продажів для кожної комбінації Каналу Трафіку та Типу Девайсу

# %%
# (UA) Створюємо зведену таблицю
# (ENG) Create the pivot table
pivot_table = pd.pivot_table(
    df_devices,
    values='price',
    index='device',
    columns='traffic_source_information',
    aggfunc='sum'
)
# (UA) Виводимо результат
# (ENG) Display the result
print("Зведена таблиця: Cума продажів для кожної комбінації Каналу Трафіку та Типу Девайсу")
print(pivot_table)
# Out:
# Зведена таблиця: Cума продажів для кожної комбінації Каналу Трафіку та Типу Девайсу
# traffic_source_information     Direct  Organic Search  Paid Search  \
# device
# desktop                      570692.3        803466.0     635232.1
# mobile                      2874772.9       4408825.1    3329687.6
# tablet                       146996.1        230168.7     204039.0
#
# traffic_source_information  Social Search  Undefined
# device
# desktop                          193635.8   153077.6
# mobile                          1006707.3   763292.9
# tablet                            78013.6    64248.9

# %% [markdown]
# # Статистичний аналіз взаємозв’язків

# %% [markdown]
# ## Кількість сесій та загальні продажі за кожну дату. Чи корелюють ці показники?

# %% [markdown]
# Діаграмма розсіювання показала що показники корелюють, від кількості сессій залежить сумма продажів. Точки  чітко шикуються в лінію, що йде з лівого нижнього кута в правий верхній. Це називається сильною позитивною кореляцією.
#
# * Позитивна: Коли один показник (кількість сесій) зростає, інший (сума продажів) теж зростає.
#
# * Сильна: Точки лежать дуже щільно навколо уявної прямої лінії.
#
#
# Рохрахунок коефіціенту кореляції Пірсона
# * Коефіціент кореляції (r): 0.791
# * P-value: 6.4835...e-21
#
# Висновок:
#
#  * Значення +0.791 — це сильна позитивна кореляція.
#  * P-value набагато менше за стандартний поріг 0.05, ми робимо висновок, що результат є статистично значущим.

# %%
# (UA) Готуємо словник
# (ENG) Prepare the dictionary
aggregations = {
    'price': 'sum',
    'session_id': 'count'
}

# (UA) Групуємо за датою та застосовуємо .agg()
# (ENG) Group by date and apply .agg()
daily_metrics = df.groupby('date').agg(aggregations)

# (UA) Перейменовуємо колонки
# (ENG) Rename columns
daily_metrics.rename(columns={'price': 'total_sales', 'session_id': 'session_count'}, inplace=True)

# (UA) Створюємо фігуру
# (ENG) Create the figure
plt.figure(figsize=(10, 6))

# (UA) Створюємо графік розсіювання
# (ENG) Create the scatterplot
sns.scatterplot(
    data=daily_metrics,
    x='total_sales',    # (UA) Ваша вісь X
    y='session_count'   # (UA) Ваша вісь Y
)

# (UA) Додаємо назви
# (ENG) Add titles
plt.title('Взаємозв’язок: Кількість сесій vs. Загальні продажі (за датою)', fontsize=14)
plt.xlabel('Загальні продажі', fontsize=12)
plt.ylabel('Кількість сесій', fontsize=12)

# (UA) Зберігаємо
# (ENG) Save
plt.tight_layout()
plt.savefig('sessions_vs_sales_scatterplot.png')

print("Графік 'sessions_vs_sales_scatterplot.png' збережено.")
print(daily_metrics.head())
# Out:
# Графік 'sessions_vs_sales_scatterplot.png' збережено.
#             total_sales  session_count
# date
# 2020-11-01     244292.5           2576
# 2020-11-02     355506.8           3599
# 2020-11-03     498979.6           5173
# 2020-11-04     339187.1           4184
# 2020-11-05     391276.6           3743

# %%
# (UA) Розраховуємо кореляцію та p-value за допомогою теста Пірсона
# (ENG) Calculating correlation and p-value using Pearson's test
r_value, p_value = pearsonr(daily_metrics['total_sales'], daily_metrics['session_count'])

print(f"Коефіцієнт кореляції (r): {r_value}")
print(f"P-value: {p_value}")
# Out:
# Коефіцієнт кореляції (r): 0.7910809164540891
# P-value: 6.483532312080735e-21

# %% [markdown]
# ## Чи корелюють між собою продажі на різних континентах? Візьми топ-3 континенти. Проаналізуй статистичну значущість взаємозв’язків.

# %%
# (UA) Знаходимо назви топ-3 континентів
# (ENG) Find the names of the top 3 continents
grouped_continent_totals = df.groupby('continent')['price'].sum().sort_values(ascending=False).head(3)
top_3_list = grouped_continent_totals.index
print("Топ-3 континенти:", top_3_list.to_list())

# (UA) Фільтруємо df, щоб залишити лише ці 3 континенти
# (ENG) Filter df to keep only these 3 continents
df_top_continents = df[df['continent'].isin(top_3_list)]

# (UA) Створюємо таблицю за допомогою pivot_table
# (ENG) Create the  table using pivot_table
daily_sales_by_continent = pd.pivot_table(
    df_top_continents,
    values='price',
    index='date',
    columns='continent',
    aggfunc='sum'
)
print("\nПідготовлена таблиця для кореляції (перші 5 рядків):")
print(daily_sales_by_continent.head())
# Пара 1: Americas vs. Asia
try:
    r_av_as, p_av_as = pearsonr(daily_sales_by_continent['Americas'], daily_sales_by_continent['Asia'])
    print(f"\n--- Кореляція: Americas vs. Asia ---")
    print(f"Коефіцієнт (r): {r_av_as:.4f}, P-value: {p_av_as}")
    if p_av_as < 0.05:
        print("Результат є Статистично значущим (p < 0.05).")
except KeyError:
    print("\nПомилка: не вдалося знайти колонки 'Americas' або 'Asia'. Перевірте ваш top_3_list.")

# Пара 2: Americas vs. Europe
try:
    r_av_eu, p_av_eu = pearsonr(daily_sales_by_continent['Americas'], daily_sales_by_continent['Europe'])
    print(f"\n--- Кореляція: Americas vs. Europe ---")
    print(f"Коефіцієнт (r): {r_av_eu:.4f}, P-value: {p_av_eu}")
    if p_av_eu < 0.05:
        print("Результат є Статистично значущим (p < 0.05).")
except KeyError:
    print("\nПомилка: не вдалося знайти колонки 'Americas' або 'Europe'. Перевірте ваш top_3_list.")

# Пара 3: Asia vs. Europe
try:
    r_as_eu, p_as_eu = pearsonr(daily_sales_by_continent['Asia'], daily_sales_by_continent['Europe'])
    print(f"\n--- Кореляція: Asia vs. Europe ---")
    print(f"Коефіцієнт (r): {r_as_eu:.4f}, P-value: {p_as_eu}")
    if p_as_eu < 0.05:
        print("Результат є Статистично значущим (p < 0.05).")
except KeyError:
    print("\nПомилка: не вдалося знайти колонки 'Asia' або 'Europe'. Перевірте ваш top_3_list.")
# Out:
# Топ-3 континенти: ['Americas', 'Asia', 'Europe']
#
# Підготовлена таблиця для кореляції (перші 5 рядків):
# continent   Americas      Asia   Europe
# date
# 2020-11-01  132002.5   63823.0  46908.0
# 2020-11-02  193861.0   79370.0  75710.8
# 2020-11-03  294529.8  126737.8  67692.0
# 2020-11-04  200009.5   66602.0  65915.0
# 2020-11-05  182988.2  117608.4  86540.0
#
# --- Кореляція: Americas vs. Asia ---
# Коефіцієнт (r): 0.7920, P-value: 5.409189396197475e-21
# Результат є Статистично значущим (p < 0.05).
#
# --- Кореляція: Americas vs. Europe ---
# Коефіцієнт (r): 0.7706, P-value: 2.6714492240629956e-19
# Результат є Статистично значущим (p < 0.05).
#
# --- Кореляція: Asia vs. Europe ---
# Коефіцієнт (r): 0.7684, P-value: 3.8649460090531196e-19
# Результат є Статистично значущим (p < 0.05).

# %% [markdown]
# ## Чи корелюють між собою продажі за різними каналами трафіку? Проаналізуй статистичну значущість взаємозв’язків.

# %%
# (UA) Створюємо "широку" таблицю
# (ENG) Create the "wide" table
sales_by_traffic = pd.pivot_table(
    df,
    values='price',
    index='date',
    columns='traffic_source_information',
    aggfunc='sum'
)

# (UA) Очищуємо NaN, замінюючи їх на 0 (важливо для кореляції)
# (ENG) Clean NaNs by replacing them with 0 (important for correlation)
sales_by_traffic = sales_by_traffic.fillna(0)

# (UA) Отримуємо список каналів для циклу
# (ENG) Get the list of channels for the loop
channel_list = sales_by_traffic.columns

print("--- Кореляційний аналіз каналів трафіку ---")

# (UA) Створюємо вкладені цикли
# (ENG) Create the nested loops
for channel1 in channel_list:
    for channel2 in channel_list:

        # (UA) Умова, щоб уникнути дублікатів
        # (ENG) The condition to avoid duplicates
        if channel1 < channel2:

            # (UA) Розраховуємо кореляцію
            # (ENG) Calculate the correlation
            r_value, p_value = pearsonr(sales_by_traffic[channel1], sales_by_traffic[channel2])

            # (UA) Виводимо результат для цієї пари
            # (ENG) Print the result for this pair
            print(f"\n--- {channel1} vs. {channel2} ---")
            print(f"Коефіцієнт (r): {r_value:.4f}")
            print(f"P-value: {p_value}")
            if p_value < 0.05:
                print("Результат є Статистично значущим (p < 0.05).")
            else:
                print("Результат НЕ є Статистично значущим (p >= 0.05).")
# Out:
# --- Кореляційний аналіз каналів трафіку ---
#
# --- Direct vs. Organic Search ---
# Коефіцієнт (r): 0.8378
# P-value: 2.1904196603645366e-25
# Результат є Статистично значущим (p < 0.05).
#
# --- Direct vs. Paid Search ---
# Коефіцієнт (r): 0.8141
# P-value: 5.896434878977516e-23
# Результат є Статистично значущим (p < 0.05).
#
# --- Direct vs. Social Search ---
# Коефіцієнт (r): 0.6041
# P-value: 1.831889246946262e-10
# Результат є Статистично значущим (p < 0.05).
#
# --- Direct vs. Undefined ---
# Коефіцієнт (r): 0.5175
# P-value: 1.2754357002002653e-07
# Результат є Статистично значущим (p < 0.05).
#
# --- Organic Search vs. Paid Search ---
# Коефіцієнт (r): 0.8701
# P-value: 2.1420029219324783e-29
# Результат є Статистично значущим (p < 0.05).
#
# --- Organic Search vs. Social Search ---
# Коефіцієнт (r): 0.5831
# P-value: 1.0661924301883206e-09
# Результат є Статистично значущим (p < 0.05).
#
# --- Organic Search vs. Undefined ---
# Коефіцієнт (r): 0.5261
# ...

# %% [markdown]
# ## Чи корелюють між собою продажі за топ-5 категоріями товарів? Проаналізуй статистичну значущість взаємозв’язків.

# %%
# (UA) Знаходимо Топ-5 категорій
# (ENG) Find the Top 5 Categories
grouped_category_totals = df.groupby('product_category')['price'].sum().sort_values(ascending=False).head(5)
top_5_list = grouped_category_totals.index
print("Топ-5 категорій:", top_5_list.to_list())

# (UA) Фільтруємо df
# (ENG) Filter the df
df_top_category = df[df['product_category'].isin(top_5_list)]

# (UA) Створюємо "широку" таблицю ---
# (ENG) Create the "wide" table ---
daily_sales_by_categories = pd.pivot_table(
    df_top_category,
    values='price',
    index='date',
    columns='product_category',
    aggfunc='sum'
)

# (UA) Очищуємо NaN, замінюючи їх на 0
# (ENG) Clean NaNs by replacing them with 0
daily_sales_by_categories = daily_sales_by_categories.fillna(0)

print("\nПідготовлена таблиця для кореляції (перші 5 рядків):")
print(daily_sales_by_categories.head())

# (UA) Кореляційний аналіз (цикл) ---
# (ENG): Correlation Analysis (Loop) ---

# (UA) Отримуємо список колонок (категорій) для циклу
# (ENG) Get the list of columns (categories) for the loop
category_list = daily_sales_by_categories.columns

print("\n--- Кореляційний аналіз Топ-5 категорій ---")

# (UA) Створюємо вкладені цикли
# (ENG) Create the nested loops
for category1 in category_list:
    for category2 in category_list:

        # (UA) Умова, щоб уникнути дублікатів (A vs B) та самопорівняння (A vs A)
        # (ENG) Condition to avoid duplicates (A vs B) and self-comparison (A vs A)
        if category1 < category2:

            # (UA) Розраховуємо кореляцію
            # (ENG) Calculate the correlation
            r_value, p_value = pearsonr(daily_sales_by_categories[category1], daily_sales_by_categories[category2])

            # (UA) Виводимо результат для цієї пари
            # (ENG) Print the result for this pair
            print(f"\n--- {category1} vs. {category2} ---")
            print(f"Коефіцієнт (r): {r_value:.4f}")
            print(f"P-value: {p_value}")

            if p_value < 0.05:
                print("Результат є Сатистично значущим (p < 0.05).")
            else:
                print("Результат НЕ є Статистично значущим (p >= 0.05).")
# Out:
# Топ-5 категорій: ['Sofas & armchairs', 'Chairs', 'Beds', 'Bookcases & shelving units', 'Cabinets & cupboards']
#
# Підготовлена таблиця для кореляції (перші 5 рядків):
# product_category     Beds  Bookcases & shelving units  Cabinets & cupboards  \
# date
# 2020-11-01        14041.0                     36701.0               13591.5
# 2020-11-02        79683.5                     40979.0               21623.0
# 2020-11-03        66219.5                     64360.1               33555.5
# 2020-11-04        48939.0                     35719.8               19266.0
# 2020-11-05        23449.0                     40998.8               29235.0
#
# product_category   Chairs  Sofas & armchairs
# date
# 2020-11-01        46006.0            75216.0
# 2020-11-02        58834.0            79977.5
# 2020-11-03        61204.0           175594.0
# 2020-11-04        44113.0            86861.5
# 2020-11-05        90388.4           137288.0
#
# --- Кореляційний аналіз Топ-5 категорій ---
#
# ...

# %% [markdown]
# ## Чи корелюють між собою продажі на різних типах девайсів?

# %%
# (UA) Створюємо "широку" таблицю (ваш код)
# (ENG) Create the "wide" table (your code)
pivot_device = pd.pivot_table(
    df,
    values='price',
    index='date',
    columns='device',
    aggfunc='sum'
)

# (UA) Очищуємо NaN, замінюючи їх на 0
# (ENG) Clean NaNs by replacing them with 0
pivot_device = pivot_device.fillna(0)

# (UA) Отримуємо список колонок (девайсів) для циклу
# (ENG) Get the list of columns (devices) for the loop
device_list = pivot_device.columns

print("--- Кореляційний аналіз типів девайсів ---")

# (UA) Створюємо вкладені цикли (ваш код)
# (ENG) Create the nested loops (your code)
for device1 in device_list:
    for device2 in device_list:

        # (UA)  Умова, щоб уникнути дублікатів (A vs B) та самопорівняння (A vs A)
        # (ENG) Condition to avoid duplicates (A vs B) and self-comparison (A vs A)
        if device1 < device2:

            # (UA) Розраховуємо кореляцію
            # (ENG) Calculate the correlation
            r_value, p_value = pearsonr(pivot_device[device1], pivot_device[device2])

            # (UA) Виводимо результат для цієї пари
            # (ENG) Print the result for this pair
            print(f"\n--- {device1} vs. {device2} ---")
            print(f"Коефіцієнт (r): {r_value:.4f}")
            print(f"P-value: {p_value}")

            if p_value < 0.05:
                print("Результат є Статистично значущим (p < 0.05).")
            else:
                print("Результат НЕ є Статистично значущим (p >= 0.05).")
# Out:
# --- Кореляційний аналіз типів девайсів ---
#
# --- desktop vs. mobile ---
# Коефіцієнт (r): 0.8732
# P-value: 7.719910860665552e-30
# Результат є Статистично значущим (p < 0.05).
#
# --- desktop vs. tablet ---
# Коефіцієнт (r): 0.6014
# P-value: 2.3168062296392482e-10
# Результат є Статистично значущим (p < 0.05).
#
# --- mobile vs. tablet ---
# Коефіцієнт (r): 0.5674
# P-value: 3.6938169231464336e-09
# Результат є Статистично значущим (p < 0.05).

# %% [markdown]
# ## Який канал трафіку є "найефективнішим"?

# %%
# (UA) Готуємо словник для агрегації
# (ENG) Prepare the aggregation dictionary
# Нам потрібні ДВІ речі для кожного каналу:
# 1. 'session_id': 'count' -> Рахує ЗАГАЛЬНУ кількість сесій
# 2. 'price': 'count'      -> Рахує лише сесії, де price НЕ NULL (тобто, ПОКУПКИ)
agg_dict = {
    'session_id': 'count',
    'price': 'count'
}

# (UA) Групуємо та агрегуємо
# (ENG) Group and aggregate
cr_data = df.groupby('traffic_source_information').agg(agg_dict)

# (UA) Перейменовуємо колонки для ясності
# (ENG) Rename columns for clarity
cr_data.rename(columns={
    'session_id': 'Total_Sessions',
    'price': 'Total_Purchases'
}, inplace=True)

# (UA) Розраховуємо Коефіцієнт Конверсії (%)
# (ENG) Calculate Conversion Rate (%)
# (Покупки / Сесії) * 100
cr_data['Conversion_Rate_Percent'] = (cr_data['Total_Purchases'] / cr_data['Total_Sessions']) * 100

# (UA) Сортуємо, щоб побачити лідерів
# (ENG) Sort to see the leaders
cr_data = cr_data.sort_values(by='Conversion_Rate_Percent', ascending=False)

# (UA) Стилізуємо таблицю для звіту
# (ENG) Style the table for the report
styled_cr_table = cr_data.style.format({
    'Total_Sessions': '{:,.0f}',         # (UA) Формат з комою (1,000)
    'Total_Purchases': '{:,.0f}',        # (UA) Формат з комою (1,000)
    'Conversion_Rate_Percent': '{:.2f}%' # (UA) 2 знаки після коми та знак %
}).background_gradient(cmap='viridis', subset=['Conversion_Rate_Percent']) # (UA) Теплова карта

print("--- Коефіцієнт Конверсії (CR) за Каналами Трафіку ---")
# (UA) Виводимо стилізовану таблицю
# (ENG) Display the styled table
styled_cr_table
# Out:
# --- Коефіцієнт Конверсії (CR) за Каналами Трафіку ---
# <style type="text/css">
# #T_080fa_row0_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_080fa_row1_col2, #T_080fa_row2_col2 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_080fa_row3_col2 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_080fa_row4_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_080fa" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_080fa_level0_col0" class="col_heading level0 col0" >Total_Sessions</th>
#       <th id="T_080fa_level0_col1" class="col_heading level0 col1" >Total_Purchases</th>
#       <th id="T_080fa_level0_col2" class="col_heading level0 col2" >Conversion_Rate_Percent</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >traffic_source_information</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
# ...

# %% [markdown]
# # Статистичний аналіз відмінностей між групами.

# %% [markdown]
# ## Проаналізуй продажі за кожну дату зареєстрованих та незареєстрованих користувачів. Створи відповідні вибірки, проаналізуй розподіли даних в обох вибірках. Підбери відповідний статистичний тест для порівняння вибірок. Зроби висновок щодо статистичної значущості отриманих результатів.

# %% [markdown]
# > ###  Аналіз: Зареєстровані vs. Незареєстровані користувачі
# >
# > Ми провели статистичний аналіз, щоб з'ясувати, чи існує значуща різниця в *сумах покупок* (чеках)  між зареєстрованими та незареєстрованими користувачами.
# >
# > #### 1. Візуальний аналіз (Box Plot )
# > * **Результат:** Графік  показав, що "коробки" (медіани та 50% даних) для груп **0 (Незареєстровані)** та **1 (Зареєстровані)** виглядають дуже схоже.
# > * **Спостереження:** Обидві групи мають багато "викидів" (outliers) — покупок на аномально великі суми, що вказує на не-нормальний розподіл.
# >
# > #### 2. Тест на нормальність (Шапіро-Вілк )
# > * **Результат:** Обидва p-value (`e-52` та `e-37`) є практично нульовими (набагато менше 0.05).
# > * **Висновок:** Дані **НЕ розподілені нормально**. Це означає, що ми не можемо використовувати T-тест і повинні обрати непараметричний аналог.
# >
# > #### 3. Фінальний тест (Манна-Вітні U-тест)
# > * **Результат:** **P-value = 0.2704**
# > * **Висновок:** Оскільки P-value (0.27) > 0.05, ми **не можемо відхилити нульову гіпотезу**.
# >
# > ---
# >
# > ####  Загальний висновок
# >
# > Незважаючи на те, що **зареєстровані користувачі роблять значно більше покупок** (1,989 проти 792), **статистично значущої різниці в сумі їхнього індивідуального "чека"** не виявлено.

# %%
# (UA) Створюємо дві вибірки, ми беремо лише ті сесії, де була покупка (price не NULL)
# (ENG) Create the two samples, we only take sessions where a purchase occurred (price is not NULL)
df_purchases = df.dropna(subset=['price'])

# (UA) Вибірка 1: Зареєстровані (де account_verified == 1)
# (ENG) Sample 1: Registered (where account_verified == 1)
sample_registered = df_purchases[df_purchases['account_verified'] == 1]['price']

# (UA) Вибірка 2: Незареєстровані (де account_verified == 0)
# (ENG) Sample 2: Unregistered (where account_verified == 0)
sample_unregistered = df_purchases[df_purchases['account_verified'] == 0]['price']

print(f"Кількість покупок (Зареєстровані): {len(sample_registered)}")
print(f"Кількість покупок (Незареєстровані): {len(sample_unregistered)}")

#(UA) Візуальний аналіз (Box Plot)
# (ENG) Visual Analysis (Box Plot)
# (UA) Нам потрібно знову об'єднати дані для seaborn
# (ENG) We need to re-combine the data for seaborn
df_all_purchases = df_purchases[df_purchases['account_verified'].isin([0, 1])]

plt.figure(figsize=(8, 6))
sns.boxplot(
    data=df_all_purchases,
    x='account_verified', # (UA) 0 vs 1
    y='price'
)
plt.title('Розподіл покупок: Зареєстровані (1) vs. Незареєстровані (0)', fontsize=14)
plt.xlabel('Тип користувача', fontsize=12)
plt.ylabel('Сума покупки', fontsize=12)
plt.savefig('registered_vs_unregistered_boxplot.png')
print("\nГрафік 'registered_vs_unregistered_boxplot.png' збережено.")

#(UA) КРОК 3: Статистичний аналіз розподілу (Тест Шапіро-Вілка)
# (ENG) STEP 3: Statistical Distribution Analysis (Shapiro-Wilk Test)
# (UA) (Примітка: Тест Шапіро повільний на великих вибірках, візьмемо 5000 випадкових)
# (ENG) (Note: Shapiro is slow on large samples, we'll take 5000 random ones)
shapiro_reg = shapiro(sample_registered.sample(min(len(sample_registered), 5000)))
shapiro_unreg = shapiro(sample_unregistered.sample(min(len(sample_unregistered), 5000)))

print(f"\nТест Шапіро (Зареєстровані) p-value: {shapiro_reg.pvalue}")
print(f"Тест Шапіро (Незареєстровані) p-value: {shapiro_unreg.pvalue}")

is_normal = (shapiro_reg.pvalue > 0.05) and (shapiro_unreg.pvalue > 0.05)
if is_normal:
    print("Висновок: Обидві вибірки виглядають нормально розподіленими.")
else:
    print("Висновок: Принаймні одна вибірка НЕ є нормально розподіленою (p < 0.05).")

#(UA) Вибір та проведення фінального тесту
#(ENG) Choose and Run the Final Test
# (UA) Оскільки дані про гроші майже ніколи не є нормальними (p < 0.05),
# (UA) ми обираємо непараметричний тест Манна-Вітні.
# (ENG) Since money data is almost never normal (p < 0.05),
# (ENG) we choose the non-parametric Mann-Whitney U test.

if not is_normal:
    print("\n--- (UA) Проводимо тест Манна-Вітні (для не-нормальних даних) ---")
    # (ENG) --- Running Mann-Whitney U Test (for non-normal data) ---
    u_stat, p_value_mw = mannwhitneyu(sample_registered, sample_unregistered, alternative='two-sided')

    print(f"U-статистика: {u_stat}")
    print(f"P-value: {p_value_mw}")

    if p_value_mw < 0.05:
        print("Результат є Статистично значущим (p < 0.05).")
        print("-> Існує значуща різниця у сумах покупок між групами.")
    else:
        print("Результат НЕ є статистично значущим (p >= 0.05).")
        print("-> Немає значущої різниці у сумах покупок між групами.")
else:
    print("\n(UA) Дані виглядають нормальними, можна було б використати t-тест.")
    # (ENG) (Data appears normal, a t-test could be used.)
# Out:
# Кількість покупок (Зареєстровані): 1989
# Кількість покупок (Незареєстровані): 792
#
# Графік 'registered_vs_unregistered_boxplot.png' збережено.
#
# Тест Шапіро (Зареєстровані) p-value: 2.8098573159514108e-52
# Тест Шапіро (Незареєстровані) p-value: 3.3425114844225247e-37
# Висновок: Принаймні одна вибірка НЕ є нормально розподіленою (p < 0.05).
#
# --- (UA) Проводимо тест Манна-Вітні (для не-нормальних даних) ---
# U-статистика: 808705.5
# P-value: 0.27041393557910354
# Результат НЕ є статистично значущим (p >= 0.05).
# -> Немає значущої різниці у сумах покупок між групами.

# %% [markdown]
# ## Проаналізуй кількість сесій за різними каналами трафіку. Підбери відповідний тест. Чи є статистично значущі відмінності між групами?

# %%
gruuped_trafic_session = pd.pivot_table(df, values = 'session_id',index='date', columns = 'traffic_source_information',aggfunc = 'count')
gruuped_trafic_session= gruuped_trafic_session.fillna(0)
print(gruuped_trafic_session)

# (UA) Отримуємо список каналів для циклу
# (ENG) Get the list of channels for the loop
trafic_list = gruuped_trafic_session.columns

print("--- Кореляційний аналіз каналів трафіку ---")

# (UA) Створюємо вкладені цикли
# (ENG) Create the nested loops
for channel1 in trafic_list:
    for channel2 in trafic_list:

        # (UA) Умова, щоб уникнути дублікатів
        # (ENG) The condition to avoid duplicates
        if channel1 < channel2:

            # (UA) Розраховуємо кореляцію
            # (ENG) Calculate the correlation
            r_value, p_value = pearsonr(gruuped_trafic_session[channel1], gruuped_trafic_session[channel2])

            # (UA) Виводимо результат для цієї пари
            # (ENG) Print the result for this pair
            print(f"\n--- {channel1} vs. {channel2} ---")
            print(f"Коефіцієнт (r): {r_value:.4f}")
            print(f"P-value: {p_value}")
            if p_value < 0.05:
                print("Результат є Статистично значущим (p < 0.05).")
            else:
                print("Результат НЕ є Статистично значущим (p >= 0.05).")
# Out:
# traffic_source_information  Direct  Organic Search  Paid Search  \
# date
# 2020-11-01                     608             920          706
# 2020-11-02                     810            1242          970
# 2020-11-03                    1216            1871         1367
# 2020-11-04                     935            1425         1145
# 2020-11-05                     845            1293          917
# ...                            ...             ...          ...
# 2021-01-27                     984            1561         1192
# 2021-01-28                     997            1379         1107
# 2021-01-29                     878            1319          988
# 2021-01-30                     685             989          787
# 2021-01-31                     644            1051          729
#
# traffic_source_information  Social Search  Undefined
# date
# 2020-11-01                            214        128
# 2020-11-02                            315        262
# ...

# %% [markdown]
# ## Чи відрізняється статистично доля сесій з органічним трафіком у Європі та Америці? Підбери відповідний тест. Проведи потрібні обчислення для створення вхідних даних до тесту.

# %%
# (UA) Визначаємо список континентів
# (ENG) Define the list of continents
america_europe = ['Americas', 'Europe']

# (UA) Фільтруємо df, щоб залишити лише 'Americas' та 'Europe'
# (ENG) Filter df to only 'Americas' and 'Europe'
america_europe_info = df[df['continent'].isin(america_europe)]

# (UA) Щоденні ОРГАНІЧНІ сесії для Європи
# (ENG) Daily ORGANIC sessions for Europe
organic_sessions_europe = america_europe_info[
    (america_europe_info['continent'] == 'Europe') &
    (america_europe_info['traffic_source_information'] == 'Organic Search')
].groupby('date')['session_id'].count()

# (UA) Щоденні ОРГАНІЧНІ сесії для Америки
# (ENG) Daily ORGANIC sessions for Americas
organic_sessions_americas = america_europe_info[
    (america_europe_info['continent'] == 'Americas') &
    (america_europe_info['traffic_source_information'] == 'Organic Search')
].groupby('date')['session_id'].count()

# (UA) Щоденні ЗАГАЛЬНІ сесії для Європи
# (ENG) Daily TOTAL sessions for Europe
total_sessions_europe_daily = america_europe_info[
    america_europe_info['continent'] == 'Europe'
].groupby('date')['session_id'].count()

# (UA) Щоденні ЗАГАЛЬНІ сесії для Америки
# (ENG) Daily TOTAL sessions for Americas
total_sessions_americas_daily = america_europe_info[
    america_europe_info['continent'] == 'Americas'
].groupby('date')['session_id'].count()

# (UA) Розраховуємо щоденну ДОЛЮ (%)
# (ENG) Calculate the daily PROPORTION (%)
# (UA) (Використовуємо .reindex().fillna(0), щоб дати збігалися)
# (ENG) (Use .reindex().fillna(0) to align the dates)
percent_organic_europe = (organic_sessions_europe / total_sessions_europe_daily).reindex(df['date'].unique(), fill_value=0)
percent_organic_americas = (organic_sessions_americas / total_sessions_americas_daily).reindex(df['date'].unique(), fill_value=0)

# (UA)  Проводимо тест Манна-Вітні
# (ENG) STEP 3: Run the Mann-Whitney U Test
# (UA) (Тест для двох НЕЗАЛЕЖНИХ вибірок, не-нормальних)
# (ENG) (Test for two INDEPENDENT, non-normal samples)
try:
    u_stat, p_value = mannwhitneyu(percent_organic_europe, percent_organic_americas, alternative='two-sided')

    print("--- Тест Манна-Вітні (Доля органічного трафіку) ---")
    print(f"Статистика U-тесту: {u_stat}")
    print(f"P-value: {p_value}")

    # (UA) Інтерпретація результату
    # (ENG) Interpretation of the result
    if p_value < 0.05:
        print("Результат є Статистично значущим (p < 0.05).")
        print("-> Існує значуща різниця в долі органічного трафіку між Європою та Америкою.")
    else:
        print("Результат НЕ є статистично значущим (p >= 0.05).")
        print("-> Немає суттєвої різниці в долі органічного трафіку між Європою та Америкою.")

except ValueError as e:
    print(f"Помилка тесту: {e}")
    print("Це могло статися, якщо одна з вибірок не має відмінностей (наприклад, всі нулі).")
# Out:
# --- Тест Манна-Вітні (Доля органічного трафіку) ---
# Статистика U-тесту: 4288.0
# P-value: 0.877891970934652
# Результат НЕ є статистично значущим (p >= 0.05).
# -> Немає суттєвої різниці в долі органічного трафіку між Європою та Америкою.

# %% [markdown]
# ## Порівнюємо середні продажі між усіма 5 каналами трафіку одночасно

# %%
# (UA) КРОК 1: Готуємо таблицю
# (ENG) STEP 1: Prepare the table
gruuped_trafic_session = pd.pivot_table(
    df,
    values='session_id',
    index='date',
    columns='traffic_source_information',
    aggfunc='count'
)

# (UA) Очищуємо NaN, замінюючи їх на 0
# (ENG) Clean NaNs by replacing them with 0
gruuped_trafic_session = gruuped_trafic_session.fillna(0)

# (UA) Створюємо список вибірок (кожна колонка - це вибірка)
# (ENG) Create a list of samples (each column is a sample)
sample_direct = gruuped_trafic_session['Direct']
sample_organic = gruuped_trafic_session['Organic Search']
sample_paid = gruuped_trafic_session['Paid Search']
sample_social = gruuped_trafic_session['Social Search']
sample_undefined = gruuped_trafic_session['Undefined']

# (UA) Проводимо тест ANOVA
# (ENG) Run the ANOVA Test
f_statistic, p_value = f_oneway(
    sample_direct,
    sample_organic,
    sample_paid,
    sample_social,
    sample_undefined
)

print("--- Тест ANOVA (F-тест) для 5 каналів трафіку ---")
print(f"F-статистика: {f_statistic}")
print(f"P-value: {p_value}")

# (UA) Інтерпретація результату
# (ENG) Interpretation of the result
if p_value < 0.05:
    print("Результат є Статистично значущим (p < 0.05).")
    print("-> Існує значуща різниця в середній кількості сесій принаймні між двома каналами.")
else:
    print("Результат НЕ є статистично значущим (p >= 0.05).")
    print("-> Немає суттєвої різниці в середній кількості сесій між каналами.")
# Out:
# --- Тест ANOVA (F-тест) для 5 каналів трафіку ---
# F-статистика: 439.7675316990713
# P-value: 8.433830529447116e-155
# Результат є Статистично значущим (p < 0.05).
# -> Існує значуща різниця в середній кількості сесій принаймні між двома каналами.
